# %%
import json
import pandas as pd
from collections import Counter
import requests

# %%
communities = []
with open('output/run142-NQv0-best_run/run142_raw_communities.json', 'r') as f:
	communities = json.load(f)

communities_list = communities['leiden']
print(len(communities_list))
# Out:
# 19

# %%
categories = pd.read_json('./categories.jsonl', lines=True)

# %%
with open('../community_analysis/nodes.json', 'r', encoding='utf-8-sig') as f:
    data = json.load(f)

nodes = pd.json_normalize(data)

# %%
categories_merged = categories.merge(
    nodes[["d.identity", "d.properties.title_encode"]],
    left_on="title",
    right_on="d.properties.title_encode",
    how="left"
)

categories_merged = categories_merged.drop(columns=["d.properties.title_encode"])
categories_merged.head()
# Out:
#             example_id                                   title  \
# 0  4549465242785278785             The_Walking_Dead_(season_8)
# 1 -2543388002166163252                              Persephone
# 2  5985355041383167183                        Colony_(biology)
# 3 -2975172535563055798  The_Man_in_the_High_Castle_(TV_series)
# 4 -1052334833502528495       List_of_heads_of_state_of_Nigeria
#
#                                           categorias  \
# 0  [2017 American television seasons, The Walking...
# 1  [Greek goddesses, Queens in Greek mythology, L...
# 2  [Community ecology, Microbiology terms, Habita...
# 3  [2010s American drama television series, 2015 ...
# 4  [Government of Nigeria, Lists of political off...
#
#                                   categorias_ocultas  d.identity
# 0  [Official website different in Wikidata and Wi...         700
# 1  [Articles containing Mycenaean Greek-language ...        6930
# 2                                                 []        6931
# 3  [CS1 German-language sources (de), Use America...        4733
# 4                 [Official website not in Wikidata]        6932

# %%
community_map = {}
for i, ids in enumerate(communities_list):
    for node_id in ids:
        community_map[node_id] = i

categories_merged['community_id'] = categories_merged['d.identity'].map(community_map)

print(f"Comunidades atribuídas: {categories_merged['community_id'].nunique()}")
# Out:
# Comunidades atribuídas: 19

# %%
categories_merged.head()
# Out:
#             example_id                                   title  \
# 0  4549465242785278785             The_Walking_Dead_(season_8)
# 1 -2543388002166163252                              Persephone
# 2  5985355041383167183                        Colony_(biology)
# 3 -2975172535563055798  The_Man_in_the_High_Castle_(TV_series)
# 4 -1052334833502528495       List_of_heads_of_state_of_Nigeria
#
#                                           categorias  \
# 0  [2017 American television seasons, The Walking...
# 1  [Greek goddesses, Queens in Greek mythology, L...
# 2  [Community ecology, Microbiology terms, Habita...
# 3  [2010s American drama television series, 2015 ...
# 4  [Government of Nigeria, Lists of political off...
#
#                                   categorias_ocultas  d.identity  community_id
# 0  [Official website different in Wikidata and Wi...         700           0.0
# 1  [Articles containing Mycenaean Greek-language ...        6930           6.0
# 2                                                 []        6931           4.0
# 3  [CS1 German-language sources (de), Use America...        4733           0.0
# 4                 [Official website not in Wikidata]        6932           2.0

# %%
# --- Contar categorias e categorias_ocultas em cada comunidade ---
top20_per_community_wiki = {}

for i in range(len(communities_list)):
    subset = categories_merged[categories_merged['community_id'] == i]

    # 'categorias' e 'categorias_ocultas' são listas — precisamos achatar
    all_cats = [cat for cats in subset['categorias'].dropna() for cat in cats]
    all_hidden = [cat for cats in subset['categorias_ocultas'].dropna() for cat in cats]

    top_cats = Counter(all_cats).most_common(20)
    top_hidden = Counter(all_hidden).most_common(20)

    top20_per_community_wiki[i] = {
        "top_categorias": top_cats,
        "top_categorias_ocultas": top_hidden
    }

# %%
top20_per_community_wiki
# Out:
# {0: {'top_categorias': [('English-language films', 16201),
#    ('American films', 14439),
#    ('English-language television programs', 9363),
#    ('Living people', 7636),
#    ('IMAX films', 3116),
#    ('American male film actors', 2877),
#    ('American male television actors', 2833),
#    ('American sequel films', 2627),
#    ('American television actresses', 2608),
#    ('American film actresses', 2503),
#    ('2010s American drama television series', 2402),
#    ('2017 films', 2221),
#    ('21st-century American actresses', 2194),
#    ('Films featuring anthropomorphic characters', 2160),
#    ('21st-century American male actors', 2101),
#    ('20th-century American male actors', 2098),
#    ('2017 American television seasons', 1994),
#    ('2010s American television series', 1989),
#    ('British films', 1931),
#    ('20th-century American actresses', 1890)],
#   'top_categorias_ocultas': [('All articles with unsourced statements', 16600),
#    ('Wikipedia articles with VIAF identifiers', 13254),
#    ('Wikipedia articles with LCCN identifiers', 10936),
#    ('Wikipedia articles with GND identifiers', 10215),
#    ('All articles needing additional references', 9766),
#    ('Webarchive template wayback links', 9439),
#    ('Articles with hCards', 9351),
#    ('Wikipedia articles with BNF identifiers', 8332),
#    ('All articles with dead external links', 6794),
#    ('Wikipedia articles with ISNI identifiers', 5936),
#    ('Articles with hAudio microformats', 5469),
#    ('Good articles', 5232),
#    ('Pages using deprecated image syntax', 4496),
#    ('Official website different in Wikidata and Wikipedia', 4353),
#    ('All articles containing potentially dated statements', 4342),
#    ('Articles with permanently dead external links', 3768),
#    ('Pages using citations with accessdate and no URL', 3589),
#    ('Music infoboxes with deprecated parameters', 3150),
#    ('Pages using infobox television with editor parameter', 2737),
#    ('Official website not in Wikidata', 2723)]},
#  1: {'top_categorias': [('Billboard Hot 100 number-one singles', 3932),
#    ('UK Singles Chart number-one singles', 3507),
#    ('Number-one singles in Australia', 2693),
#    ('Irish Singles Chart number-one singles', 2406),
#    ('RPM Top Singles number-one singles', 2318),
#    ('Billboard Adult Contemporary number-one singles', 2296),
#    ('Pop ballads', 2128),
#    ('Columbia Records singles', 2020),
#    ('Number-one singles in New Zealand', 1960),
#    ('Debut singles', 1653),
#    ('Number-one singles in Norway', 1607),
#    ('Billboard Hot R&amp;B/Hip-Hop Songs number-one singles', 1500),
#    ('Billboard Hot Country Songs number-one singles', 1474),
#    ('Rock ballads', 1459),
#    ('Dutch Top 40 number-one singles', 1379),
#    ('Number-one singles in Germany', 1366),
#    ('European Hot 100 Singles number-one singles', 1312),
#    ('Number-one singles in Sweden', 1304),
#    ('Number-one singles in Switzerland', 1280),
#    ('Living people', 1214)],
#   'top_categorias_ocultas': [('Articles with hAudio microformats', 22546),
#    ('Singlechart called without song', 9552),
#    ('All articles with unsourced statements', 8692),
#    ('Singlechart usages for Billboardhot100', 7201),
#    ('Singlechart called without artist', 6792),
#    ('Music infoboxes with deprecated parameters', 6332),
#    ('Singlechart usages for New Zealand', 6091),
#    ('All articles needing additional references', 5889),
#    ('Certification Table Entry usages for United States', 5819),
#    ('Singlechart usages for Austria', 5656),
#    ('Singlechart usages for Dutch100', 5553),
#    ('Certification Table Entry usages for United Kingdom', 5421),
#    ('Singlechart usages for Flanders', 5377),
#    ('Singlechart usages for Australia', 5128),
#    ('Singlechart usages for Sweden', 4907),
#    ('Webarchive template wayback links', 4881),
#    ('Singlechart usages for UK', 4848),
#    ('Singlechart usages for France', 4624),
#    ('Singlechart usages for Dutch40', 4492),
#    ('Singlechart usages for Switzerland', 4477)]},
#  2: {'top_categorias': [('Member states of the United Nations', 678),
#    ('Visa requirements by nationality', 512),
#    ('Living people', 429),
#    ('Lists of countries', 400),
#    ('English-speaking countries and territories', 324),
#    ('Minimum ages', 315),
#    ('Republics', 293),
#    ('Wars involving the United States', 287),
#    ('Wars involving the United Kingdom', 267),
#    ('Law-related lists', 249),
#    ('Lists by country', 245),
#    ('National flags', 241),
#    ('World War I', 234),
#    ('Wars involving France', 233),
#    ('Soviet Unionâ\x80\x93United States relations', 232),
#    ('Traffic law', 230),
#    ('Global conflicts', 226),
#    ('Member states of the Commonwealth of Nations', 226),
#    ('Proxy wars', 219),
#    ('Visa policy by country', 216)],
#   'top_categorias_ocultas': [('All articles with unsourced statements', 13960),
#    ('Webarchive template wayback links', 11014),
#    ('All articles needing additional references', 7367),
#    ('All articles with dead external links', 6393),
#    ('Wikipedia articles with GND identifiers', 6121),
#    ('Coordinates on Wikidata', 4303),
#    ('Articles with permanently dead external links', 4236),
#    ('Wikipedia articles with VIAF identifiers', 4215),
#    ('All articles containing potentially dated statements', 3595),
#    ('Wikipedia articles with LCCN identifiers', 3376),
#    ('Wikipedia articles with BNF identifiers', 2703),
#    ('CS1 French-language sources (fr)', 2496),
#    ('CS1 Spanish-language sources (es)', 2494),
#    ('Articles with hAudio microformats', 2096),
#    ('CS1 German-language sources (de)', 2050),
#    ('Wikipedia indefinitely move-protected pages', 1978),
#    ('Articles containing French-language text', 1952),
#    ('CS1 maint: Multiple names: authors list', 1783),
#    ('All articles lacking reliable references', 1732),
#    ('Pages using deprecated image syntax', 1662)]},
#  3: {'top_categorias': [('Legal history of the United States', 624),
#    ('History of United States expansionism', 579),
#    ('Amendments to the United States Constitution', 562),
#    ('States of the United States', 491),
#    ('Wars involving the United States', 486),
#    ('History of the United States (1865â\x80\x931918)', 480),
#    ('1789 establishments in the United States', 454),
#    ('History of the United States (1776â\x80\x9389)', 441),
#    ('United States Supreme Court cases', 434),
#    ('American Revolution', 433),
#    ('Historic Civil Engineering Landmarks', 416),
#    ('History of the United States (1789â\x80\x931849)', 394),
#    ('United States historical documents', 383),
#    ('National symbols of the United States', 379),
#    ('Legislative branch of the United States government', 352),
#    ('Official documents of the United States', 332),
#    ('Colonization history of the United States', 326),
#    ('Progressive Era in the United States', 323),
#    ('United States Declaration of Independence', 321),
#    ('Clauses of the United States Constitution', 318)],
#   'top_categorias_ocultas': [('All articles with unsourced statements', 15589),
#    ('Webarchive template wayback links', 12799),
#    ('Coordinates on Wikidata', 8069),
#    ('All articles needing additional references', 7480),
#    ('All articles with dead external links', 7373),
#    ('Wikipedia articles with GND identifiers', 6458),
#    ('Wikipedia articles with VIAF identifiers', 5589),
#    ('Wikipedia articles with LCCN identifiers', 4987),
#    ('All articles containing potentially dated statements', 4522),
#    ('Articles with permanently dead external links', 4233),
#    ('CS1: Julianâ\x80\x93Gregorian uncertainty', 3467),
#    ('CS1 maint: Multiple names: authors list', 2953),
#    ('Pages using deprecated image syntax', 2672),
#    ('Wikipedia indefinitely move-protected pages', 2572),
#    ('Wikipedia articles with BNF identifiers', 2548),
#    ('Wikipedia indefinitely semi-protected pages', 2408),
#    ('Wikipedia articles with ISNI identifiers', 2217),
#    ('All Wikipedia articles written in American English', 2214),
#    ('CS1 maint: Extra text: authors list', 2115),
#    ('Articles with hAudio microformats', 2022)]},
#  4: {'top_categorias': [('Wikipedia articles incorporating text from the 20th edition of Gray&#39;s Anatomy (1918)',
#     453),
#    ('Metabolism', 403),
#    ('IUCN Red List least concern species', 381),
#    ('Cellular respiration', 366),
#    ('Digestive system', 339),
#    ('Plant physiology', 300),
#    ('Cell biology', 270),
#    ('Molecular biology', 250),
#    ('Photosynthesis', 248),
#    ('Plate tectonics', 244),
#    ('Membrane biology', 236),
#    ('Skeletal system', 223),
#    ('Organs (anatomy)', 204),
#    ('Taxa named by Carl Linnaeus', 200),
#    ('Oceanographical terminology', 199),
#    ('Nutrition', 197),
#    ('Cell anatomy', 193),
#    ('Genetics', 189),
#    ('Organelles', 185),
#    ('Cardiac anatomy', 181)],
#   'top_categorias_ocultas': [('All articles with unsourced statements', 10393),
#    ('Webarchive template wayback links', 4956),
#    ('All articles needing additional references', 4512),
#    ('Wikipedia articles with GND identifiers', 4507),
#    ('CS1 maint: Multiple names: authors list', 3529),
#    ('All articles with dead external links', 2599),
#    ('Articles with &#39;species&#39; microformats', 2450),
#    ('Articles with permanently dead external links', 1743),
#    ('CS1 maint: Uses authors parameter', 1678),
#    ('Pages with unresolved properties', 1645),
#    ('Wikipedia articles with LCCN identifiers', 1476),
#    ('Articles containing video clips', 1376),
#    ('Wikipedia articles with NDL identifiers', 1361),
#    ('Wikipedia indefinitely move-protected pages', 1251),
#    ('Wikipedia indefinitely semi-protected pages', 1197),
#    ('CS1 maint: Extra text: authors list', 1136),
#    ('Good articles', 1111),
#    ('All articles lacking reliable references', 1110),
#    ('CS1 maint: Explicit use of et al.', 1017),
#    ('All articles to be expanded', 974)]},
#  5: {'top_categorias': [('All-wheel-drive vehicles', 475),
#    ('2000s automobiles', 457),
#    ('2010s automobiles', 452),
#    ('Rear-wheel-drive vehicles', 362),
#    ('Front-wheel-drive vehicles', 329),
#    ('Motor vehicles manufactured in the United States', 303),
#    ('1990s automobiles', 268),
#    ('Concepts in physics', 265),
#    ('Chemical elements', 228),
#    ('Physical quantities', 222),
#    ('CoupÃ©s', 211),
#    ('American inventions', 207),
#    ('Periodic table', 189),
#    ('Sedans', 185),
#    ('Hatchbacks', 165),
#    ('Chemical properties', 164),
#    ('Chemical bonding', 156),
#    ('1980s automobiles', 155),
#    ('Units of time', 153),
#    ('Crossover sport utility vehicles', 151)],
#   'top_categorias_ocultas': [('All articles with unsourced statements', 6575),
#    ('Webarchive template wayback links', 4013),
#    ('Wikipedia articles with GND identifiers', 3672),
#    ('All articles needing additional references', 3616),
#    ('All articles with dead external links', 2117),
#    ('Wikipedia articles with LCCN identifiers', 1516),
#    ('Articles with permanently dead external links', 1388),
#    ('Articles containing video clips', 1300),
#    ('CS1 maint: Multiple names: authors list', 1283),
#    ('All articles containing potentially dated statements', 1180),
#    ('CS1 German-language sources (de)', 981),
#    ('Wikipedia articles with BNF identifiers', 937),
#    ('Wikipedia indefinitely semi-protected pages', 823),
#    ('Wikipedia indefinitely move-protected pages', 792),
#    ('Good articles', 744),
#    ('Wikipedia articles with NDL identifiers', 705),
#    ('Featured articles', 661),
#    ('CS1: Julianâ\x80\x93Gregorian uncertainty', 641),
#    ('CS1 French-language sources (fr)', 617),
#    ('All articles lacking reliable references', 555)]},
#  6: {'top_categorias': [('Christian terminology', 1130),
#    ('Biblical phrases', 383),
#    ('Former empires', 245),
#    ('Former countries in Europe', 242),
#    ('Former countries in Asia', 206),
#    ('English-language idioms', 186),
#    ('New Testament books', 179),
#    ('Former countries in Africa', 178),
#    ('Islamic terminology', 171),
#    ('Chinese architectural history', 170),
#    ('Great Wall of China', 166),
#    ('French Revolution', 148),
#    ('Hebrew Bible words and phrases', 142),
#    ('Cultural lists', 138),
#    ('Book of Genesis', 136),
#    ('American films', 132),
#    ('Historical eras', 132),
#    ('English-language films', 131),
#    ('Canonical epistles', 130),
#    ('1789 events of the French Revolution', 130)],
#   'top_categorias_ocultas': [('All articles with unsourced statements', 8584),
#    ('Wikipedia articles with GND identifiers', 5381),
#    ('Webarchive template wayback links', 4624),
#    ('All articles needing additional references', 3699),
#    ('Wikipedia articles with VIAF identifiers', 3277),
#    ('Wikipedia articles with LCCN identifiers', 2736),
#    ('Wikipedia articles with BNF identifiers', 2653),
#    ('Articles containing Ancient Greek-language text', 2382),
#    ('All articles with dead external links', 2089),
#    ('Articles containing Latin-language text', 1953),
#    ('Coordinates on Wikidata', 1909),
#    ('Articles containing Hebrew-language text', 1317),
#    ('Articles with permanently dead external links', 1220),
#    ('Articles containing French-language text', 1215),
#    ('All articles lacking reliable references', 1194),
#    ('Articles containing Arabic-language text', 1187),
#    ('All articles with specifically marked weasel-worded phrases', 1185),
#    ('Articles with hAudio microformats', 1147),
#    ('CS1 maint: Extra text: authors list', 1145),
#    ('Interlanguage link template link number', 1128)]},
#  7: {'top_categorias': [('Indian films', 833),
#    ('Living people', 423),
#    ('Hindi-language films', 346),
#    ('Constitution of India', 341),
#    ('Hindi-language television programs', 320),
#    ('Parliament of India', 293),
#    ('History of Bengal', 285),
#    ('History of Pakistan', 284),
#    ('Independent India', 280),
#    ('2010s Indian television series', 277),
#    ('History of West Bengal', 276),
#    ('Indian independence movement', 261),
#    ('Indian drama television series', 255),
#    ('2010s Hindi-language films', 248),
#    ('History of Kolkata', 240),
#    ('Indian reality television series', 226),
#    ('History of Bangladesh', 225),
#    ('Star Plus television series', 219),
#    ('Political history of India', 207),
#    ('British East India Company', 195)],
#   'top_categorias_ocultas': [('All Wikipedia articles written in Indian English',
#     7385),
#    ('All articles with unsourced statements', 4247),
#    ('Webarchive template wayback links', 3030),
#    ('All articles needing additional references', 2918),
#    ('Coordinates on Wikidata', 1836),
#    ('All articles with dead external links', 1814),
#    ('Wikipedia articles with GND identifiers', 1299),
#    ('Wikipedia articles with VIAF identifiers', 1260),
#    ('Articles with permanently dead external links', 1202),
#    ('Articles with hAudio microformats', 1164),
#    ('All articles containing potentially dated statements', 1002),
#    ('Wikipedia articles with LCCN identifiers', 882),
#    ('Use Indian English from June 2016', 849),
#    ('Use dmy dates from March 2013', 800),
#    ('All articles lacking reliable references', 772),
#    ('Articles with hCards', 763),
#    ('Wikipedia articles with BNF identifiers', 746),
#    ('Wikipedia indefinitely semi-protected pages', 706),
#    ('CS1 maint: Extra text: authors list', 690),
#    ('Wikipedia articles with ISNI identifiers', 680)]},
#  8: {'top_categorias': [('Windows games', 842),
#    ('Xbox One games', 649),
#    ('PlayStation 4 games', 544),
#    ('Manga series', 514),
#    ('Xbox 360 games', 462),
#    ('Multiplayer and single-player video games', 376),
#    ('Video games developed in the United States', 373),
#    ('Funimation', 360),
#    ('Open world video games', 342),
#    ('MacOS games', 319),
#    ('PlayStation 3 games', 314),
#    ('ShÅ\x8dnen manga', 312),
#    ('Action-adventure games', 309),
#    ('Lists of anime episodes', 275),
#    ('American inventions', 269),
#    ('IOS games', 266),
#    ('Single-player video games', 259),
#    ('Dragon Ball episode lists', 244),
#    ('Video games developed in Japan', 237),
#    ('IOS (Apple)', 235)],
#   'top_categorias_ocultas': [('All articles with unsourced statements', 4418),
#    ('Articles containing Japanese-language text', 2148),
#    ('All articles needing additional references', 2119),
#    ('Webarchive template wayback links', 1871),
#    ('CS1 Japanese-language sources (ja)', 1773),
#    ('All articles containing potentially dated statements', 1427),
#    ('Wikipedia articles with GND identifiers', 1228),
#    ('Official website different in Wikidata and Wikipedia', 1156),
#    ('Articles using Infobox video game using locally defined parameters',
#     1152),
#    ('Articles using Wikidata infoboxes with locally defined images', 1135),
#    ('CS1 uses Japanese-language script (ja)', 1084),
#    ('All articles with dead external links', 1030),
#    ('Pages using deprecated image syntax', 967),
#    ('Articles with Japanese-language external links', 821),
#    ('Articles using Video game reviews template in single platform mode', 793),
#    ('Articles with permanently dead external links', 661),
#    ('Articles using small message boxes', 584),
#    ('Wikipedia articles with LCCN identifiers', 573),
#    ('All articles to be expanded', 558),
#    ('Pages using RFC magic links', 548)]},
#  9: {'top_categorias': [('Business terms', 184),
#    ('Production economics', 131),
#    ('Contract law', 126),
#    ('Legal doctrines and principles', 121),
#    ('Sociological theories', 113),
#    ('Criminal law', 112),
#    ('Sociological terminology', 109),
#    ('Capitalism', 107),
#    ('Accounting terminology', 103),
#    ('Legal terminology', 101),
#    ('Philosophy of science', 99),
#    ('Educational psychology', 98),
#    ('Scientific method', 92),
#    ('Criminal procedure', 90),
#    ('Economic systems', 89),
#    ('Business law', 89),
#    ('Political philosophy', 85),
#    ('Latin legal terminology', 84),
#    ('English phrases', 84),
#    ('Design of experiments', 83)],
#   'top_categorias_ocultas': [('All articles with unsourced statements', 4581),
#    ('All articles needing additional references', 2227),
#    ('Webarchive template wayback links', 2077),
#    ('Wikipedia articles with GND identifiers', 2048),
#    ('All articles with dead external links', 1074),
#    ('CS1 maint: Multiple names: authors list', 806),
#    ('All articles with specifically marked weasel-worded phrases', 758),
#    ('Wikipedia articles with LCCN identifiers', 726),
#    ('Articles with permanently dead external links', 683),
#    ('Wikipedia articles with NDL identifiers', 572),
#    ('Articles with multiple maintenance issues', 492),
#    ('Wikipedia articles with BNF identifiers', 482),
#    ('All articles to be expanded', 456),
#    ('Articles using small message boxes', 448),
#    ('CS1 maint: Extra text: authors list', 395),
#    ('All pages needing cleanup', 380),
#    ('All articles that may contain original research', 374),
#    ('Pages using citations with accessdate and no URL', 372),
#    ('All stub articles', 359),
#    ('All articles lacking in-text citations', 358)]},
#  10: {'top_categorias': [('Living people', 1263),
#    ('National Basketball Association lists', 894),
#    ('National Football League teams', 882),
#    ('Lists of sports championships', 433),
#    ('Major League Baseball teams', 408),
#    ('Major League Baseball lists', 407),
#    ('National Basketball Association statistical leaders', 390),
#    ('Super Bowl', 388),
#    ('African-American basketball players', 383),
#    ('Annual sporting events in the United States', 345),
#    ('National Basketball Association All-Stars', 315),
#    ('World Series', 300),
#    ('United States men&#39;s national basketball team players', 286),
#    ('Parade High School All-Americans (boys&#39; basketball)', 279),
#    ('Super Bowl lists', 277),
#    ('National Basketball Association teams', 266),
#    ('Sports clubs established in 1960', 266),
#    ('McDonald&#39;s High School All-Americans', 265),
#    ('American football quarterbacks', 259),
#    ('Olympic gold medalists for the United States in basketball', 257)],
#   'top_categorias_ocultas': [('All articles with unsourced statements', 4465),
#    ('Webarchive template wayback links', 3671),
#    ('Articles with hCards', 3082),
#    ('All articles with dead external links', 2838),
#    ('All articles needing additional references', 2543),
#    ('Articles with permanently dead external links', 1694),
#    ('Wikipedia articles with VIAF identifiers', 1275),
#    ('Wikipedia articles with LCCN identifiers', 1241),
#    ('Featured lists', 1212),
#    ('Pages using deprecated image syntax', 1054),
#    ('All articles containing potentially dated statements', 883),
#    ('Coordinates on Wikidata', 823),
#    ('Wikipedia indefinitely semi-protected pages', 805),
#    ('Wikipedia pages semi-protected against vandalism', 750),
#    ('Good articles', 663),
#    ('Wikipedia articles with GND identifiers', 615),
#    ('Pages using citations with accessdate and no URL', 600),
#    ('Pages with citations lacking titles', 600),
#    ('Official website different in Wikidata and Wikipedia', 595),
#    ('Pages containing links to subscription-only content', 592)]},
#  11: {'top_categorias': [('Surnames', 601),
#    ('Countries at the FIFA World Cup', 522),
#    ('2018 FIFA World Cup', 515),
#    ('FIFA World Cup tournaments', 458),
#    ('Living people', 455),
#    ('FIFA World Cup-related lists', 388),
#    ('Association football records and statistics', 350),
#    ('FIFA World Cup statistics', 255),
#    ('Association football forwards', 245),
#    ('Premier League players', 236),
#    ('British monarchy', 230),
#    ('La Liga players', 224),
#    ('History of the England national football team', 216),
#    ('2018 in association football', 213),
#    ('International association football competitions hosted by Russia', 212),
#    ('UEFA Champions League winning players', 207),
#    ('July 2018 sports events in Europe', 206),
#    ('June 2018 sports events in Europe', 205),
#    ('England at the FIFA World Cup', 204),
#    ('Football clubs in England', 204)],
#   'top_categorias_ocultas': [('All articles with unsourced statements', 3325),
#    ('Webarchive template wayback links', 2846),
#    ('All articles needing additional references', 1910),
#    ('All articles with dead external links', 1745),
#    ('Wikipedia articles with GND identifiers', 1402),
#    ('Articles with permanently dead external links', 1272),
#    ('Wikipedia articles with VIAF identifiers', 1226),
#    ('Coordinates on Wikidata', 1116),
#    ('Articles with hCards', 1079),
#    ('Wikipedia articles with LCCN identifiers', 1025),
#    ('CS1 Spanish-language sources (es)', 960),
#    ('Pages using deprecated image syntax', 867),
#    ('All articles containing potentially dated statements', 724),
#    ('All set index articles', 640),
#    ('Pages containing links to subscription-only content', 632),
#    ('Featured articles', 625),
#    ('Wikipedia articles with ISNI identifiers', 615),
#    ('Wikipedia articles with BNF identifiers', 610),
#    ('Articles with short description', 581),
#    ('CS1 Italian-language sources (it)', 569)]},
#  12: {'top_categorias': [('Fast-food chains of the United States', 268),
#    ('Fast-food franchises', 194),
#    ('Las Vegas Strip', 169),
#    ('RMS Titanic', 133),
#    ('Restaurant chains in the United States', 131),
#    ('Skyscraper hotels in Paradise, Nevada', 102),
#    ('1912 in Canada', 99),
#    ('1912 in the United Kingdom', 99),
#    ('1912 in the United States', 99),
#    ('Casino hotels', 98),
#    ('Casinos in the Las Vegas Valley', 94),
#    ('Resorts in the Las Vegas Valley', 93),
#    ('Fast-food hamburger restaurants', 88),
#    ('Maritime incidents in 1912', 83),
#    ('Regional restaurant chains in the United States', 81),
#    ('1910s in Newfoundland', 80),
#    ('Ship collisions with icebergs', 80),
#    ('Ships sunk in collisions', 79),
#    ('1911 ships', 78),
#    ('History of Halifax, Nova Scotia', 78)],
#   'top_categorias_ocultas': [('All articles with unsourced statements', 585),
#    ('All articles needing additional references', 301),
#    ('Webarchive template wayback links', 294),
#    ('Coordinates on Wikidata', 288),
#    ('Pages using deprecated image syntax', 264),
#    ('All articles with dead external links', 211),
#    ('All articles containing potentially dated statements', 186),
#    ('Wikipedia articles with LCCN identifiers', 180),
#    ('Wikipedia articles with VIAF identifiers', 179),
#    ('Pages containing links to subscription-only content', 164),
#    ('Official website different in Wikidata and Wikipedia', 163),
#    ('Wikipedia articles with GND identifiers', 134),
#    ('Pages using citations with accessdate and no URL', 131),
#    ('Wikipedia indefinitely semi-protected pages', 119),
#    ('Wikipedia indefinitely move-protected pages', 104),
#    ('CS1 maint: BOT: original-url status unknown', 91),
#    ('Articles with hAudio microformats', 89),
#    ('Articles with permanently dead external links', 84),
#    ('Good articles', 73),
#    ('Wikipedia articles with SNAC-ID identifiers', 71)]},
#  13: {'top_categorias': [('The Office (U.S. TV series) characters', 151),
#    ('Fictional characters introduced in 2005', 122),
#    ('The Office (U.S. TV series) episodes in multiple parts', 70),
#    ('Fictional American people of English descent', 61),
#    ('Fictional receptionists', 56),
#    ('Fictional secretaries', 50),
#    ('2009 American television episodes', 47),
#    ('The Office (U.S. season 9) episodes', 46),
#    ('2007 American television episodes', 43),
#    ('The Office (U.S. season 3) episodes', 38),
#    ('The Office (U.S. season 5) episodes', 34),
#    ('The Office (U.S. season 6) episodes', 33),
#    ('The Office (U.S. season 8) episodes', 28),
#    ('Television episodes about weddings', 28),
#    ('2013 American television episodes', 27),
#    ('Fictional salespeople', 27),
#    ('Fictional American people of Scottish descent', 27),
#    ('2012 American television seasons', 25),
#    ('2011 American television episodes', 24),
#    ('The Office (U.S. season 2) episodes', 21)],
#   'top_categorias_ocultas': [('Good articles', 180),
#    ('Tv.com template using numeric id', 113),
#    ('All articles that need to differentiate between fact and fiction', 93),
#    ('All articles with dead external links', 70),
#    ('Articles that need to differentiate between fact and fiction from December 2015',
#     69),
#    ('Webarchive template wayback links', 67),
#    ('Use mdy dates from January 2018', 60),
#    ('All articles needing additional references', 59),
#    ('Pages using deprecated image syntax', 59),
#    ('TV.com template using numeric id', 58),
#    ('Articles needing additional references from November 2012', 50),
#    ('Articles with multiple maintenance issues', 47),
#    ('Articles with permanently dead external links', 42),
#    ('Pages using infobox character with unknown parameters', 37),
#    ('Pages containing links to subscription-only content', 34),
#    ('Articles with short description', 31),
#    ('Featured lists', 25),
#    ('Television episode articles with short description for single episodes',
#     24),
#    ('All articles lacking reliable references', 20),
#    ('Articles with dead external links from June 2017', 20)]},
#  14: {'top_categorias': [('Days of Our Lives characters', 203),
#    ('Living people', 44),
#    ('Days of Our Lives', 38),
#    ('Fictional American people of Irish descent', 29),
#    ('Fictional American people of English descent', 29),
#    ('Lists of actors by soap opera television series', 26),
#    ('American soap opera actresses', 25),
#    ('Fictional businesspeople', 18),
#    ('American television actresses', 18),
#    ('Fictional lawyers', 17),
#    ('Fictional murderers', 16),
#    ('Fictional characters introduced in 1996', 16),
#    ('American male soap opera actors', 16),
#    ('Fictional rapists', 16),
#    ('Fictional gay males', 15),
#    ('Fictional LGBT characters in television', 15),
#    ('Fictional African-American people', 15),
#    ('Fictional characters introduced in 1982', 14),
#    ('Fictional sexual assault victims', 13),
#    ('Fictional American police officers', 13)],
#   'top_categorias_ocultas': [('Pages using citations with accessdate and no URL',
#     57),
#    ('Articles with multiple maintenance issues', 48),
#    ('Articles with hCards', 44),
#    ('All articles that need to differentiate between fact and fiction', 43),
#    ('All articles needing additional references', 34),
#    ('Wikipedia articles with incorrect tenses', 25),
#    ('Wikipedia pages semi-protected against vandalism', 25),
#    ('All articles with dead external links', 25),
#    ('All articles with unsourced statements', 24),
#    ('All articles to be expanded', 22),
#    ('All articles lacking sources', 21),
#    ('All BLP articles lacking sources', 19),
#    ('All Wikipedia articles with plot summary needing attention', 18),
#    ('Articles with permanently dead external links', 13),
#    ('Articles that need to differentiate between fact and fiction from January 2010',
#     12),
#    ('CS1 French-language sources (fr)', 12),
#    ('Pages with citations having bare URLs', 12),
#    ('Articles with unsourced statements from September 2017', 11),
#    ('Pages with citations lacking titles', 11),
#    ('Pages using web citations with no URL', 10)]},
#  15: {'top_categorias': [('Roud Folk Song Index songs', 271),
#    ('English nursery rhymes', 254),
#    ('Children&#39;s songs', 158),
#    ('Year of song unknown', 132),
#    ('Songwriter unknown', 114),
#    ('Singing games', 99),
#    ('Lullabies', 46),
#    ('American nursery rhymes', 44),
#    ('English folk songs', 43),
#    ('1790s in England', 42),
#    ('1881 songs', 42),
#    ('1881 in England', 42),
#    ('Urban legends', 42),
#    ('English folklore', 33),
#    ('Songs about London', 33),
#    ('Riddles', 30),
#    ('Nursery rhymes', 29),
#    ('Songs about children', 28),
#    ('Music education', 27),
#    ('Songs about women', 27)],
#   'top_categorias_ocultas': [('Articles with hAudio microformats', 166),
#    ('Good articles', 106),
#    ('All articles with unsourced statements', 91),
#    ('All articles needing additional references', 63),
#    ('CS1 maint: Extra text: authors list', 49),
#    ('CS1: Julianâ\x80\x93Gregorian uncertainty', 39),
#    ('All articles lacking reliable references', 37),
#    ('Webarchive template wayback links', 29),
#    ('All articles with dead external links', 24),
#    ('Articles with dead external links from July 2017', 22),
#    ('Use dmy dates from January 2015', 22),
#    ('Articles containing potentially dated statements from April 2008', 22),
#    ('All articles containing potentially dated statements', 22),
#    ('Articles lacking reliable references from May 2015', 22),
#    ('Use dmy dates from July 2012', 18),
#    ('Commons category with page title different than on Wikidata', 18),
#    ('Articles with trivia sections from March 2017', 14),
#    ('All articles with trivia sections', 14),
#    ('Articles with unsourced statements from December 2017', 12),
#    ('Articles with unsourced statements from July 2012', 12)]},
#  16: {'top_categorias': [('Coronation Street characters', 71),
#    ('Fictional bartenders', 26),
#    ('Fictional businesspeople', 23),
#    ('Fictional victims of kidnapping', 16),
#    ('Fictional British people', 16),
#    ('Lists of Coronation Street characters', 15),
#    ('Living people', 13),
#    ('Coronation Street', 13),
#    ('Fictional English people of Irish descent', 13),
#    ('Fictional English people', 12),
#    ('Fictional factory workers', 11),
#    ('Fictional British people of Irish descent', 11),
#    ('Fictional characters introduced in 2006', 10),
#    ('Fictional twins', 9),
#    ('Fictional taxicab drivers', 9),
#    ('Fictional domestic abusers', 8),
#    ('Fictional waiting staff', 7),
#    ('English television actresses', 7),
#    ('Female characters in television', 7),
#    ('Fictional teenage parents', 7)],
#   'top_categorias_ocultas': [('Use British English from March 2014', 38),
#    ('Use dmy dates from March 2014', 28),
#    ('Pages using deprecated image syntax', 22),
#    ('All articles with unsourced statements', 16),
#    ('Articles with hCards', 12),
#    ('All articles with dead external links', 11),
#    ('Pages using citations with accessdate and no URL', 11),
#    ('Use dmy dates from October 2013', 10),
#    ('CS1 maint: Extra text: authors list', 10),
#    ('Use dmy dates from March 2011', 9),
#    ('Wikipedia semi-protected pages', 8),
#    ('EngvarB from November 2017', 7),
#    ('Use dmy dates from November 2017', 7),
#    ('EngvarB from October 2013', 7),
#    ('All articles that need to differentiate between fact and fiction', 7),
#    ('Use British English from June 2016', 7),
#    ('All articles needing additional references', 7),
#    ('Use dmy dates from July 2018', 6),
#    ('Articles that need to differentiate between fact and fiction from December 2013',
#     6),
#    ('Wikipedia articles needing clarification from October 2016', 6)]},
#  17: {'top_categorias': [('United States gun laws by state', 332),
#    ('Texas law', 48),
#    ('Gun politics in the United States', 45),
#    ('Self-defense', 44),
#    ('United States firearms law', 29),
#    ('Licenses', 28),
#    ('Michigan law', 21),
#    ('Indiana law', 18),
#    ('Homicide', 16),
#    ('Legal doctrines and principles', 16),
#    ('U.S. state criminal law', 16),
#    ('Controversies in the United States', 16),
#    ('New York (state) law', 16),
#    ('Virginia law', 14),
#    ('Florida law', 13),
#    ('California law', 12),
#    ('North Carolina law', 12),
#    ('Missouri law', 10),
#    ('Washington (state) law', 10),
#    ('Colorado law', 10)],
#   'top_categorias_ocultas': [('All articles with unsourced statements', 103),
#    ('Webarchive template wayback links', 79),
#    ('Pages with citations lacking titles', 62),
#    ('Pages with citations having bare URLs', 62),
#    ('All articles lacking reliable references', 42),
#    ('Articles with unsourced statements from June 2016', 36),
#    ('All articles containing potentially dated statements', 35),
#    ('All articles needing additional references', 35),
#    ('Pages using web citations with no URL', 27),
#    ('Articles with unsourced statements from December 2010', 26),
#    ('Articles with unsourced statements from August 2017', 22),
#    ('Use mdy dates from February 2014', 21),
#    ('Articles lacking reliable references from December 2015', 21),
#    ('CS1 errors: external links', 19),
#    ('All articles with dead external links', 18),
#    ('Articles with unsourced statements from March 2015', 18),
#    ('Articles with unsourced statements from March 2016', 18),
#    ('Articles with unsourced statements from February 2015', 18),
#    ('Articles with unsourced statements from August 2013', 18),
#    ('Articles with unsourced statements from September 2013', 18)]},
#  18: {'top_categorias': [('Home and Away characters', 63),
#    ('Lists of Home and Away characters', 47),
#    ('Fictional characters introduced in 1988', 29),
#    ('Fictional businesspeople', 19),
#    ('Fictional teenage parents', 15),
#    ('Fictional waiting staff', 14),
#    ('Lists of actors by soap opera television series', 14),
#    ('Fictional people from New South Wales', 13),
#    ('Fictional characters introduced in 2015', 11),
#    ('Fictional characters introduced in 2017', 10),
#    ('2017 in Australian television', 10),
#    ('Fictional shopkeepers', 10),
#    ('Fictional schoolteachers', 9),
#    ('Fictional victims of kidnapping', 8),
#    ('Fictional characters introduced in 1989', 7),
#    ('Fictional murderers', 7),
#    ('Fictional characters introduced in 2013', 7),
#    ('Living people', 7),
#    ('Fictional characters introduced in 2018', 7),
#    ('2018 in Australian television', 7)],
#   'top_categorias_ocultas': [('Pages using deprecated image syntax', 44),
#    ('All Wikipedia articles written in Australian English', 32),
#    ('Pages using citations with accessdate and no URL', 32),
#    ('Articles with attributed pull quotes', 29),
#    ('Pages containing links to subscription-only content', 22),
#    ('Articles with hCards', 21),
#    ('Use dmy dates from July 2017', 17),
#    ('Use Australian English from July 2017', 17),
#    ('Use dmy dates from October 2013', 15),
#    ('EngvarB from October 2013', 13),
#    ('EngvarB from November 2017', 9),
#    ('Use dmy dates from November 2017', 9),
#    ('Pages with reference errors', 8),
#    ('Pages with duplicate reference names', 8),
#    ('Pages using citations with format and no URL', 4),
#    ('Good articles', 4),
#    ('Use dmy dates from November 2012', 4),
#    ('All stub articles', 4),
#    ('Use dmy dates from January 2013', 4),
#    ('Use Australian English from January 2013', 4)]}}

# %%
# Ler o arquivo JSON correto
with open('output/run142-NQv0-best_run/run142_community_keywords.json', 'r', encoding='utf-8') as f:
    data = json.load(f)

# Criar uma lista para o DataFrame
rows = []

# Iterar por todos os algoritmos e comunidades
for algorithm_name, communities in data.items():
    for comm_id, comm_data in communities.items():
        # Extrair keywords (apenas as palavras, sem as contagens)
        keywords = comm_data.get('keywords', [])
        keywords_list = [kw[0] for kw in keywords]
        keywords_string = ', '.join(keywords_list)
        
        rows.append({
            'algorithm': algorithm_name,
            'community_id': comm_id,
            'comm_name': comm_data.get('comm_name', ''),
            'keywords_string': keywords_string,
            'num_keywords': len(keywords_list)
        })

# Criar DataFrame
df = pd.DataFrame(rows)

print(df)
# Out:
#      algorithm community_id                            comm_name  \
# 0      infomap            0  Countries, History, European, World
# 1      infomap            1            States, United, New, York
# 2      infomap            2         Cell, System, Human, Disease
# 3      infomap            3    Computer, Software, Data, Windows
# 4      infomap            4    Church, Catholic, Bible, Biblical
# ...        ...          ...                                  ...
# 1327   k-means           35           Engine, Ford, Car, Vehicle
# 1328   k-means           36           Star, Film, Series, Comics
# 1329   k-means           37               Girl, Film, She, Woman
# 1330   k-means           38             States, United, Act, Law
# 1331   k-means           39    School, University, High, College
#
#                                         keywords_string  num_keywords
# 0     countries, history, european, world, economy, ...            10
# 1     states, united, new, york, state, national, ac...            10
# 2     cell, system, human, disease, muscle, history,...            10
# 3     computer, software, data, windows, system, pro...            10
# 4     church, catholic, bible, biblical, history, go...            10
# ...                                                 ...           ...
# 1327  engine, ford, car, vehicle, grand, prix, toyot...            10
# 1328  star, film, series, comics, wars, trek, season...            10
# 1329  girl, film, she, woman, queen, you, lady, litt...            10
# 1330  states, united, act, law, rights, federal, cou...            10
# 1331  school, university, high, college, institute, ...            10
#
# [1332 rows x 5 columns]

# %%
import requests
import pandas as pd

def categorize_with_ollama(keywords_string, model="mistral"):
    prompt = f"""
You are a precise classifier. Analyze the following keywords produced by a community detection algorithm and identify the main themes.

Keywords:
{keywords_string}

Task: Generate between 1 and 3 category names that best describe the community. Each category should be 2-4 words maximum.
- Use 1 category if the keywords represent a single coherent theme
- Use 2-3 categories if multiple distinct but related themes are present

Return ONLY the category names separated by semicolons (;). No explanations, no numbering, no extra text.
Example format: "machine learning; artificial intelligence" or "biology"
"""

    data = {
        "model": model,
        "prompt": prompt,
        "stream": False,
        "options": {
            "seed": 42,
            "top_k": 1,
            "top_p": 1,
            "temperature": 0
        }
    }

    url = "http://localhost:11434/api/generate"
    headers = {"Content-Type": "application/json"}

    try:
        resp = requests.post(url, headers=headers, json=data, timeout=3000)
        resp.raise_for_status()
        result = resp.json()
        return result.get("response", "").strip().lower()
    except Exception as e:
        print(f"Erro ao categorizar: {e}")
        return "erro"

# %%
df.iloc[0]['keywords_string']
# Out:
# 'countries, history, european, world, economy, national, republic, flag, union, languages'

# %%
categorize_with_ollama('countries, history, european, world, economy, national, republic, flag, union, languages')
# Out:
# 'european history; geopolitics; economy'

# %%
# Remove todos do algorithm=infomap
df = df[df['algorithm'] == 'leiden']
#exclui coluna descriptions
df
# Out:
#      algorithm community_id                               comm_name  \
# 1273    leiden            0          Film, Series, Season, Episodes
# 1274    leiden            1                  Song, You, Love, Album
# 1275    leiden            2               World, War, South, United
# 1276    leiden            3              States, United, New, State
# 1277    leiden            4           Cell, History, Human, Cuisine
# 1278    leiden            5           Power, System, Energy, Engine
# 1279    leiden            6         History, Church, Roman, Ancient
# 1280    leiden            7        India, Indian, Cricket, National
# 1281    leiden            8         Episodes, Computer, Video, Game
# 1282    leiden            9         Law, Theory, Social, Management
# 1283    leiden           10  Football, League, Basketball, Baseball
# 1284    leiden           11             Cup, Surname, United, World
# 1285    leiden           12                Las, Vegas, Card, Casino
# 1286    leiden           13          Office, Season, Paper, Michael
# 1287    leiden           14                 Brady, Days, Our, Lives
# 1288    leiden           15                 Little, Nyah, Old, Baby
# 1289    leiden           16  Coronation, Street, Characters, Barlow
# 1290    leiden           17                   Gun, Laws, New, Carry
# 1291    leiden           18         Home, Away, Characters, Stewart
#
#                                         keywords_string  num_keywords
# 1273  film, series, season, episodes, characters, ma...            10
# 1274  song, you, love, album, music, don, all, your,...            10
# 1275  world, war, south, united, history, olympics, ...            10
# 1276  states, united, new, state, act, york, america...            10
# 1277  cell, history, human, cuisine, system, disease...            10
# 1278  power, system, energy, engine, history, ford, ...            10
# 1279  history, church, roman, ancient, art, god, bib...            10
# 1280  india, indian, cricket, national, pakistan, in...            10
# 1281  episodes, computer, video, game, software, sys...            10
# 1282  law, theory, social, management, analysis, his...            10
# 1283  football, league, basketball, baseball, season...            10
# 1284  cup, surname, united, world, fifa, kingdom, fo...            10
# 1285  las, vegas, card, casino, poker, game, titanic...            10
# 1286  office, season, paper, michael, day, night, an...            10
# 1287  brady, days, our, lives, dimera, characters, h...            10
# 1288  little, nyah, old, baby, mary, rain, down, man...            10
# 1289  coronation, street, characters, barlow, connor...            10
# 1290  gun, laws, new, carry, united, states, califor...            10
# 1291  home, away, characters, stewart, braxton, king...            10

# %%
import time
from concurrent.futures import ThreadPoolExecutor, as_completed

print("\nCategorizando comunidades com Ollama...")

def process_row(idx, row):
    """Função auxiliar que processa uma linha do DataFrame."""
    print(f"Processando {row['algorithm']} - comunidade {row['community_id']}...")
    category = categorize_with_ollama(row['keywords_string'])
    time.sleep(1)
    print(f"  -> Rows keywords: {row['keywords_string']}")
    print(f"  -> Categoria: {category}")
    return idx, category

results = []
with ThreadPoolExecutor(max_workers=32) as executor:
    futures = {executor.submit(process_row, idx, row): idx for idx, row in df.iterrows()}
    total = len(futures)
    processed = 0

    for future in as_completed(futures):
        idx, category = future.result()
        df.at[idx, 'category'] = category
        processed += 1
        if processed % 10 == 0 or processed == total:
            print(f"Processados {processed}/{total}")

print("\n=== DataFrame Final ===")
print(df.head(10))
# Out:
# Categorizando comunidades com Ollama...
# Processando leiden - comunidade 0...
# Processando leiden - comunidade 1...
# Processando leiden - comunidade 2...
# Processando leiden - comunidade 3...
# Processando leiden - comunidade 4...
# Processando leiden - comunidade 5...
# Processando leiden - comunidade 6...
# Processando leiden - comunidade 7...
# Processando leiden - comunidade 8...
# Processando leiden - comunidade 9...
# Processando leiden - comunidade 10...
# Processando leiden - comunidade 11...
# Processando leiden - comunidade 12...
# Processando leiden - comunidade 13...
# Processando leiden - comunidade 14...
# Processando leiden - comunidade 15...
# Processando leiden - comunidade 16...
# Processando leiden - comunidade 17...
# Processando leiden - comunidade 18...
#   -> Rows keywords: cell, history, human, cuisine, system, disease, food, medical, american, muscle
#   -> Categoria: medical history; american cuisine; human health
#   -> Rows keywords: states, united, new, state, act, york, american, national, california, history
#   -> Categoria: united states history; american states; national & state affairs
#   -> Rows keywords: film, series, season, episodes, characters, man, you, actor, star, show
#   -> Categoria: film & tv content; actors & characters
#   -> Rows keywords: episodes, computer, video, game, software, system, data, games, history, network
#   -> Categoria: computer games history; video game software; network systems data
#   -> Rows keywords: song, you, love, album, music, don, all, your, that, what
#   -> Categoria: music & albums; love songs
#   -> Rows keywords: world, war, south, united, history, olympics, canada, australia, africa, national
#   -> Categoria: global affairs; geography; sports & competitions
#   -> Rows keywords: history, church, roman, ancient, art, god, bible, empire, catholic, book
#   -> Categoria: ancient roman art & religion; catholic history & empire
#   -> Rows keywords: las, vegas, card, casino, poker, game, titanic, rms, seas, hotel
#   -> Categoria: gambling & entertainment; las vegas; maritime
#   -> Rows keywords: power, system, energy, engine, history, ford, solar, series, space, number
#   -> Categoria: power systems; energy sources; historical vehicles
#   -> Rows keywords: home, away, characters, stewart, braxton, king, casey, darryl, ailsa, kirsty
#   -> Categoria: characters at home; workplace characters
# Processados 10/19
#   -> Rows keywords: law, theory, social, management, analysis, history, psychology, market, model, tax
#   -> Categoria: legal & social studies; management & market analysis; psychology & taxation models
#   -> Rows keywords: football, league, basketball, baseball, season, national, major, state, bowl, men
#   -> Categoria: sports competitions; american team sports; seasons
#   -> Rows keywords: india, indian, cricket, national, pakistan, institute, film, technology, history, world
#   -> Categoria: sports & culture; south asia; education & technology
#   -> Rows keywords: brady, days, our, lives, dimera, characters, horton, hernandez, carver, kiriakis
#   -> Categoria: "days of our lives characters"; "horton-dimera family"; "kiriakis-carver connection"
#   -> Rows keywords: cup, surname, united, world, fifa, kingdom, football, national, england, league
#   -> Categoria: football community; united kingdom; fifa matters
#   -> Rows keywords: gun, laws, new, carry, united, states, california, carolina, virginia, concealed
#   -> Categoria: gun laws in us states; concealed carry regulations (california, virginia, carolina)
#   -> Rows keywords: little, nyah, old, baby, mary, rain, down, man, row, round
#   -> Categoria: "baby animals; weather; miscellaneous"
#   -> Rows keywords: office, season, paper, michael, day, night, andy, series, toby, dunder
#   -> Categoria: office workers; tv series characters
#   -> Rows keywords: coronation, street, characters, barlow, connor, platt, baldwin, roache, webster, michelle
#   -> Categoria: coronation street characters; british soap opera cast
# Processados 19/19
#
# === DataFrame Final ===
#      algorithm community_id                         comm_name  \
# 1273    leiden            0    Film, Series, Season, Episodes
# 1274    leiden            1            Song, You, Love, Album
# 1275    leiden            2         World, War, South, United
# 1276    leiden            3        States, United, New, State
# 1277    leiden            4     Cell, History, Human, Cuisine
# 1278    leiden            5     Power, System, Energy, Engine
# 1279    leiden            6   History, Church, Roman, Ancient
# 1280    leiden            7  India, Indian, Cricket, National
# 1281    leiden            8   Episodes, Computer, Video, Game
# 1282    leiden            9   Law, Theory, Social, Management
#
#                                         keywords_string  num_keywords  \
# 1273  film, series, season, episodes, characters, ma...            10
# 1274  song, you, love, album, music, don, all, your,...            10
# 1275  world, war, south, united, history, olympics, ...            10
# 1276  states, united, new, state, act, york, america...            10
# 1277  cell, history, human, cuisine, system, disease...            10
# 1278  power, system, energy, engine, history, ford, ...            10
# 1279  history, church, roman, ancient, art, god, bib...            10
# 1280  india, indian, cricket, national, pakistan, in...            10
# 1281  episodes, computer, video, game, software, sys...            10
# 1282  law, theory, social, management, analysis, his...            10
#
#                                                category
# 1273             film & tv content; actors & characters
# 1274                         music & albums; love songs
# 1275   global affairs; geography; sports & competitions
# 1276  united states history; american states; nation...
# 1277    medical history; american cuisine; human health
# 1278  power systems; energy sources; historical vehi...
# 1279  ancient roman art & religion; catholic history...
# 1280  sports & culture; south asia; education & tech...
# 1281  computer games history; video game software; n...
# 1282  legal & social studies; management & market an...

# %%
df
# Out:
#      algorithm community_id                               comm_name  \
# 1273    leiden            0          Film, Series, Season, Episodes
# 1274    leiden            1                  Song, You, Love, Album
# 1275    leiden            2               World, War, South, United
# 1276    leiden            3              States, United, New, State
# 1277    leiden            4           Cell, History, Human, Cuisine
# 1278    leiden            5           Power, System, Energy, Engine
# 1279    leiden            6         History, Church, Roman, Ancient
# 1280    leiden            7        India, Indian, Cricket, National
# 1281    leiden            8         Episodes, Computer, Video, Game
# 1282    leiden            9         Law, Theory, Social, Management
# 1283    leiden           10  Football, League, Basketball, Baseball
# 1284    leiden           11             Cup, Surname, United, World
# 1285    leiden           12                Las, Vegas, Card, Casino
# 1286    leiden           13          Office, Season, Paper, Michael
# 1287    leiden           14                 Brady, Days, Our, Lives
# 1288    leiden           15                 Little, Nyah, Old, Baby
# 1289    leiden           16  Coronation, Street, Characters, Barlow
# 1290    leiden           17                   Gun, Laws, New, Carry
# 1291    leiden           18         Home, Away, Characters, Stewart
#
#                                         keywords_string  num_keywords  \
# 1273  film, series, season, episodes, characters, ma...            10
# 1274  song, you, love, album, music, don, all, your,...            10
# 1275  world, war, south, united, history, olympics, ...            10
# 1276  states, united, new, state, act, york, america...            10
# 1277  cell, history, human, cuisine, system, disease...            10
# 1278  power, system, energy, engine, history, ford, ...            10
# 1279  history, church, roman, ancient, art, god, bib...            10
# 1280  india, indian, cricket, national, pakistan, in...            10
# 1281  episodes, computer, video, game, software, sys...            10
# 1282  law, theory, social, management, analysis, his...            10
# 1283  football, league, basketball, baseball, season...            10
# 1284  cup, surname, united, world, fifa, kingdom, fo...            10
# 1285  las, vegas, card, casino, poker, game, titanic...            10
# 1286  office, season, paper, michael, day, night, an...            10
# 1287  brady, days, our, lives, dimera, characters, h...            10
# 1288  little, nyah, old, baby, mary, rain, down, man...            10
# 1289  coronation, street, characters, barlow, connor...            10
# 1290  gun, laws, new, carry, united, states, califor...            10
# 1291  home, away, characters, stewart, braxton, king...            10
#
#                                                category
# 1273             film & tv content; actors & characters
# 1274                         music & albums; love songs
# 1275   global affairs; geography; sports & competitions
# 1276  united states history; american states; nation...
# 1277    medical history; american cuisine; human health
# 1278  power systems; energy sources; historical vehi...
# 1279  ancient roman art & religion; catholic history...
# 1280  sports & culture; south asia; education & tech...
# 1281  computer games history; video game software; n...
# 1282  legal & social studies; management & market an...
# 1283  sports competitions; american team sports; sea...
# 1284   football community; united kingdom; fifa matters
# 1285      gambling & entertainment; las vegas; maritime
# 1286               office workers; tv series characters
# 1287  "days of our lives characters"; "horton-dimera...
# 1288             "baby animals; weather; miscellaneous"
# 1289  coronation street characters; british soap ope...
# 1290  gun laws in us states; concealed carry regulat...
# 1291           characters at home; workplace characters

# %%
df.to_json('communities_categorized.json', orient='records', indent=2)
print("\nResultados salvos em communities_categorized.json ✅")
# Out:
# Resultados salvos em communities_categorized.json ✅

# %%
df = pd.read_json('communities_categorized.json', orient='records')
df
# Out:
#    algorithm  community_id                               comm_name  \
# 0     leiden             0          Film, Series, Season, Episodes
# 1     leiden             1                  Song, You, Love, Album
# 2     leiden             2               World, War, South, United
# 3     leiden             3              States, United, New, State
# 4     leiden             4           Cell, History, Human, Cuisine
# 5     leiden             5           Power, System, Energy, Engine
# 6     leiden             6         History, Church, Roman, Ancient
# 7     leiden             7        India, Indian, Cricket, National
# 8     leiden             8         Episodes, Computer, Video, Game
# 9     leiden             9         Law, Theory, Social, Management
# 10    leiden            10  Football, League, Basketball, Baseball
# 11    leiden            11             Cup, Surname, United, World
# 12    leiden            12                Las, Vegas, Card, Casino
# 13    leiden            13          Office, Season, Paper, Michael
# 14    leiden            14                 Brady, Days, Our, Lives
# 15    leiden            15                 Little, Nyah, Old, Baby
# 16    leiden            16  Coronation, Street, Characters, Barlow
# 17    leiden            17                   Gun, Laws, New, Carry
# 18    leiden            18         Home, Away, Characters, Stewart
#
#                                       keywords_string  num_keywords  \
# 0   film, series, season, episodes, characters, ma...            10
# 1   song, you, love, album, music, don, all, your,...            10
# 2   world, war, south, united, history, olympics, ...            10
# 3   states, united, new, state, act, york, america...            10
# 4   cell, history, human, cuisine, system, disease...            10
# 5   power, system, energy, engine, history, ford, ...            10
# 6   history, church, roman, ancient, art, god, bib...            10
# 7   india, indian, cricket, national, pakistan, in...            10
# 8   episodes, computer, video, game, software, sys...            10
# 9   law, theory, social, management, analysis, his...            10
# 10  football, league, basketball, baseball, season...            10
# 11  cup, surname, united, world, fifa, kingdom, fo...            10
# 12  las, vegas, card, casino, poker, game, titanic...            10
# 13  office, season, paper, michael, day, night, an...            10
# 14  brady, days, our, lives, dimera, characters, h...            10
# 15  little, nyah, old, baby, mary, rain, down, man...            10
# 16  coronation, street, characters, barlow, connor...            10
# 17  gun, laws, new, carry, united, states, califor...            10
# 18  home, away, characters, stewart, braxton, king...            10
#
#                                              category
# 0              film & tv content; actors & characters
# 1                          music & albums; love songs
# 2    global affairs; geography; sports & competitions
# 3   united states history; american states; nation...
# 4     medical history; american cuisine; human health
# 5   power systems; energy sources; historical vehi...
# 6   ancient roman art & religion; catholic history...
# 7   sports & culture; south asia; education & tech...
# 8   computer games history; video game software; n...
# 9   legal & social studies; management & market an...
# 10  sports competitions; american team sports; sea...
# 11   football community; united kingdom; fifa matters
# 12      gambling & entertainment; las vegas; maritime
# 13               office workers; tv series characters
# 14  "days of our lives characters"; "horton-dimera...
# 15             "baby animals; weather; miscellaneous"
# 16  coronation street characters; british soap ope...
# 17  gun laws in us states; concealed carry regulat...
# 18           characters at home; workplace characters

# %%
top20_per_community_wiki
# Out:
# {0: {'top_categorias': [('English-language films', 16201),
#    ('American films', 14439),
#    ('English-language television programs', 9363),
#    ('Living people', 7636),
#    ('IMAX films', 3116),
#    ('American male film actors', 2877),
#    ('American male television actors', 2833),
#    ('American sequel films', 2627),
#    ('American television actresses', 2608),
#    ('American film actresses', 2503),
#    ('2010s American drama television series', 2402),
#    ('2017 films', 2221),
#    ('21st-century American actresses', 2194),
#    ('Films featuring anthropomorphic characters', 2160),
#    ('21st-century American male actors', 2101),
#    ('20th-century American male actors', 2098),
#    ('2017 American television seasons', 1994),
#    ('2010s American television series', 1989),
#    ('British films', 1931),
#    ('20th-century American actresses', 1890)],
#   'top_categorias_ocultas': [('All articles with unsourced statements', 16600),
#    ('Wikipedia articles with VIAF identifiers', 13254),
#    ('Wikipedia articles with LCCN identifiers', 10936),
#    ('Wikipedia articles with GND identifiers', 10215),
#    ('All articles needing additional references', 9766),
#    ('Webarchive template wayback links', 9439),
#    ('Articles with hCards', 9351),
#    ('Wikipedia articles with BNF identifiers', 8332),
#    ('All articles with dead external links', 6794),
#    ('Wikipedia articles with ISNI identifiers', 5936),
#    ('Articles with hAudio microformats', 5469),
#    ('Good articles', 5232),
#    ('Pages using deprecated image syntax', 4496),
#    ('Official website different in Wikidata and Wikipedia', 4353),
#    ('All articles containing potentially dated statements', 4342),
#    ('Articles with permanently dead external links', 3768),
#    ('Pages using citations with accessdate and no URL', 3589),
#    ('Music infoboxes with deprecated parameters', 3150),
#    ('Pages using infobox television with editor parameter', 2737),
#    ('Official website not in Wikidata', 2723)]},
#  1: {'top_categorias': [('Billboard Hot 100 number-one singles', 3932),
#    ('UK Singles Chart number-one singles', 3507),
#    ('Number-one singles in Australia', 2693),
#    ('Irish Singles Chart number-one singles', 2406),
#    ('RPM Top Singles number-one singles', 2318),
#    ('Billboard Adult Contemporary number-one singles', 2296),
#    ('Pop ballads', 2128),
#    ('Columbia Records singles', 2020),
#    ('Number-one singles in New Zealand', 1960),
#    ('Debut singles', 1653),
#    ('Number-one singles in Norway', 1607),
#    ('Billboard Hot R&amp;B/Hip-Hop Songs number-one singles', 1500),
#    ('Billboard Hot Country Songs number-one singles', 1474),
#    ('Rock ballads', 1459),
#    ('Dutch Top 40 number-one singles', 1379),
#    ('Number-one singles in Germany', 1366),
#    ('European Hot 100 Singles number-one singles', 1312),
#    ('Number-one singles in Sweden', 1304),
#    ('Number-one singles in Switzerland', 1280),
#    ('Living people', 1214)],
#   'top_categorias_ocultas': [('Articles with hAudio microformats', 22546),
#    ('Singlechart called without song', 9552),
#    ('All articles with unsourced statements', 8692),
#    ('Singlechart usages for Billboardhot100', 7201),
#    ('Singlechart called without artist', 6792),
#    ('Music infoboxes with deprecated parameters', 6332),
#    ('Singlechart usages for New Zealand', 6091),
#    ('All articles needing additional references', 5889),
#    ('Certification Table Entry usages for United States', 5819),
#    ('Singlechart usages for Austria', 5656),
#    ('Singlechart usages for Dutch100', 5553),
#    ('Certification Table Entry usages for United Kingdom', 5421),
#    ('Singlechart usages for Flanders', 5377),
#    ('Singlechart usages for Australia', 5128),
#    ('Singlechart usages for Sweden', 4907),
#    ('Webarchive template wayback links', 4881),
#    ('Singlechart usages for UK', 4848),
#    ('Singlechart usages for France', 4624),
#    ('Singlechart usages for Dutch40', 4492),
#    ('Singlechart usages for Switzerland', 4477)]},
#  2: {'top_categorias': [('Member states of the United Nations', 678),
#    ('Visa requirements by nationality', 512),
#    ('Living people', 429),
#    ('Lists of countries', 400),
#    ('English-speaking countries and territories', 324),
#    ('Minimum ages', 315),
#    ('Republics', 293),
#    ('Wars involving the United States', 287),
#    ('Wars involving the United Kingdom', 267),
#    ('Law-related lists', 249),
#    ('Lists by country', 245),
#    ('National flags', 241),
#    ('World War I', 234),
#    ('Wars involving France', 233),
#    ('Soviet Unionâ\x80\x93United States relations', 232),
#    ('Traffic law', 230),
#    ('Global conflicts', 226),
#    ('Member states of the Commonwealth of Nations', 226),
#    ('Proxy wars', 219),
#    ('Visa policy by country', 216)],
#   'top_categorias_ocultas': [('All articles with unsourced statements', 13960),
#    ('Webarchive template wayback links', 11014),
#    ('All articles needing additional references', 7367),
#    ('All articles with dead external links', 6393),
#    ('Wikipedia articles with GND identifiers', 6121),
#    ('Coordinates on Wikidata', 4303),
#    ('Articles with permanently dead external links', 4236),
#    ('Wikipedia articles with VIAF identifiers', 4215),
#    ('All articles containing potentially dated statements', 3595),
#    ('Wikipedia articles with LCCN identifiers', 3376),
#    ('Wikipedia articles with BNF identifiers', 2703),
#    ('CS1 French-language sources (fr)', 2496),
#    ('CS1 Spanish-language sources (es)', 2494),
#    ('Articles with hAudio microformats', 2096),
#    ('CS1 German-language sources (de)', 2050),
#    ('Wikipedia indefinitely move-protected pages', 1978),
#    ('Articles containing French-language text', 1952),
#    ('CS1 maint: Multiple names: authors list', 1783),
#    ('All articles lacking reliable references', 1732),
#    ('Pages using deprecated image syntax', 1662)]},
#  3: {'top_categorias': [('Legal history of the United States', 624),
#    ('History of United States expansionism', 579),
#    ('Amendments to the United States Constitution', 562),
#    ('States of the United States', 491),
#    ('Wars involving the United States', 486),
#    ('History of the United States (1865â\x80\x931918)', 480),
#    ('1789 establishments in the United States', 454),
#    ('History of the United States (1776â\x80\x9389)', 441),
#    ('United States Supreme Court cases', 434),
#    ('American Revolution', 433),
#    ('Historic Civil Engineering Landmarks', 416),
#    ('History of the United States (1789â\x80\x931849)', 394),
#    ('United States historical documents', 383),
#    ('National symbols of the United States', 379),
#    ('Legislative branch of the United States government', 352),
#    ('Official documents of the United States', 332),
#    ('Colonization history of the United States', 326),
#    ('Progressive Era in the United States', 323),
#    ('United States Declaration of Independence', 321),
#    ('Clauses of the United States Constitution', 318)],
#   'top_categorias_ocultas': [('All articles with unsourced statements', 15589),
#    ('Webarchive template wayback links', 12799),
#    ('Coordinates on Wikidata', 8069),
#    ('All articles needing additional references', 7480),
#    ('All articles with dead external links', 7373),
#    ('Wikipedia articles with GND identifiers', 6458),
#    ('Wikipedia articles with VIAF identifiers', 5589),
#    ('Wikipedia articles with LCCN identifiers', 4987),
#    ('All articles containing potentially dated statements', 4522),
#    ('Articles with permanently dead external links', 4233),
#    ('CS1: Julianâ\x80\x93Gregorian uncertainty', 3467),
#    ('CS1 maint: Multiple names: authors list', 2953),
#    ('Pages using deprecated image syntax', 2672),
#    ('Wikipedia indefinitely move-protected pages', 2572),
#    ('Wikipedia articles with BNF identifiers', 2548),
#    ('Wikipedia indefinitely semi-protected pages', 2408),
#    ('Wikipedia articles with ISNI identifiers', 2217),
#    ('All Wikipedia articles written in American English', 2214),
#    ('CS1 maint: Extra text: authors list', 2115),
#    ('Articles with hAudio microformats', 2022)]},
#  4: {'top_categorias': [('Wikipedia articles incorporating text from the 20th edition of Gray&#39;s Anatomy (1918)',
#     453),
#    ('Metabolism', 403),
#    ('IUCN Red List least concern species', 381),
#    ('Cellular respiration', 366),
#    ('Digestive system', 339),
#    ('Plant physiology', 300),
#    ('Cell biology', 270),
#    ('Molecular biology', 250),
#    ('Photosynthesis', 248),
#    ('Plate tectonics', 244),
#    ('Membrane biology', 236),
#    ('Skeletal system', 223),
#    ('Organs (anatomy)', 204),
#    ('Taxa named by Carl Linnaeus', 200),
#    ('Oceanographical terminology', 199),
#    ('Nutrition', 197),
#    ('Cell anatomy', 193),
#    ('Genetics', 189),
#    ('Organelles', 185),
#    ('Cardiac anatomy', 181)],
#   'top_categorias_ocultas': [('All articles with unsourced statements', 10393),
#    ('Webarchive template wayback links', 4956),
#    ('All articles needing additional references', 4512),
#    ('Wikipedia articles with GND identifiers', 4507),
#    ('CS1 maint: Multiple names: authors list', 3529),
#    ('All articles with dead external links', 2599),
#    ('Articles with &#39;species&#39; microformats', 2450),
#    ('Articles with permanently dead external links', 1743),
#    ('CS1 maint: Uses authors parameter', 1678),
#    ('Pages with unresolved properties', 1645),
#    ('Wikipedia articles with LCCN identifiers', 1476),
#    ('Articles containing video clips', 1376),
#    ('Wikipedia articles with NDL identifiers', 1361),
#    ('Wikipedia indefinitely move-protected pages', 1251),
#    ('Wikipedia indefinitely semi-protected pages', 1197),
#    ('CS1 maint: Extra text: authors list', 1136),
#    ('Good articles', 1111),
#    ('All articles lacking reliable references', 1110),
#    ('CS1 maint: Explicit use of et al.', 1017),
#    ('All articles to be expanded', 974)]},
#  5: {'top_categorias': [('All-wheel-drive vehicles', 475),
#    ('2000s automobiles', 457),
#    ('2010s automobiles', 452),
#    ('Rear-wheel-drive vehicles', 362),
#    ('Front-wheel-drive vehicles', 329),
#    ('Motor vehicles manufactured in the United States', 303),
#    ('1990s automobiles', 268),
#    ('Concepts in physics', 265),
#    ('Chemical elements', 228),
#    ('Physical quantities', 222),
#    ('CoupÃ©s', 211),
#    ('American inventions', 207),
#    ('Periodic table', 189),
#    ('Sedans', 185),
#    ('Hatchbacks', 165),
#    ('Chemical properties', 164),
#    ('Chemical bonding', 156),
#    ('1980s automobiles', 155),
#    ('Units of time', 153),
#    ('Crossover sport utility vehicles', 151)],
#   'top_categorias_ocultas': [('All articles with unsourced statements', 6575),
#    ('Webarchive template wayback links', 4013),
#    ('Wikipedia articles with GND identifiers', 3672),
#    ('All articles needing additional references', 3616),
#    ('All articles with dead external links', 2117),
#    ('Wikipedia articles with LCCN identifiers', 1516),
#    ('Articles with permanently dead external links', 1388),
#    ('Articles containing video clips', 1300),
#    ('CS1 maint: Multiple names: authors list', 1283),
#    ('All articles containing potentially dated statements', 1180),
#    ('CS1 German-language sources (de)', 981),
#    ('Wikipedia articles with BNF identifiers', 937),
#    ('Wikipedia indefinitely semi-protected pages', 823),
#    ('Wikipedia indefinitely move-protected pages', 792),
#    ('Good articles', 744),
#    ('Wikipedia articles with NDL identifiers', 705),
#    ('Featured articles', 661),
#    ('CS1: Julianâ\x80\x93Gregorian uncertainty', 641),
#    ('CS1 French-language sources (fr)', 617),
#    ('All articles lacking reliable references', 555)]},
#  6: {'top_categorias': [('Christian terminology', 1130),
#    ('Biblical phrases', 383),
#    ('Former empires', 245),
#    ('Former countries in Europe', 242),
#    ('Former countries in Asia', 206),
#    ('English-language idioms', 186),
#    ('New Testament books', 179),
#    ('Former countries in Africa', 178),
#    ('Islamic terminology', 171),
#    ('Chinese architectural history', 170),
#    ('Great Wall of China', 166),
#    ('French Revolution', 148),
#    ('Hebrew Bible words and phrases', 142),
#    ('Cultural lists', 138),
#    ('Book of Genesis', 136),
#    ('American films', 132),
#    ('Historical eras', 132),
#    ('English-language films', 131),
#    ('Canonical epistles', 130),
#    ('1789 events of the French Revolution', 130)],
#   'top_categorias_ocultas': [('All articles with unsourced statements', 8584),
#    ('Wikipedia articles with GND identifiers', 5381),
#    ('Webarchive template wayback links', 4624),
#    ('All articles needing additional references', 3699),
#    ('Wikipedia articles with VIAF identifiers', 3277),
#    ('Wikipedia articles with LCCN identifiers', 2736),
#    ('Wikipedia articles with BNF identifiers', 2653),
#    ('Articles containing Ancient Greek-language text', 2382),
#    ('All articles with dead external links', 2089),
#    ('Articles containing Latin-language text', 1953),
#    ('Coordinates on Wikidata', 1909),
#    ('Articles containing Hebrew-language text', 1317),
#    ('Articles with permanently dead external links', 1220),
#    ('Articles containing French-language text', 1215),
#    ('All articles lacking reliable references', 1194),
#    ('Articles containing Arabic-language text', 1187),
#    ('All articles with specifically marked weasel-worded phrases', 1185),
#    ('Articles with hAudio microformats', 1147),
#    ('CS1 maint: Extra text: authors list', 1145),
#    ('Interlanguage link template link number', 1128)]},
#  7: {'top_categorias': [('Indian films', 833),
#    ('Living people', 423),
#    ('Hindi-language films', 346),
#    ('Constitution of India', 341),
#    ('Hindi-language television programs', 320),
#    ('Parliament of India', 293),
#    ('History of Bengal', 285),
#    ('History of Pakistan', 284),
#    ('Independent India', 280),
#    ('2010s Indian television series', 277),
#    ('History of West Bengal', 276),
#    ('Indian independence movement', 261),
#    ('Indian drama television series', 255),
#    ('2010s Hindi-language films', 248),
#    ('History of Kolkata', 240),
#    ('Indian reality television series', 226),
#    ('History of Bangladesh', 225),
#    ('Star Plus television series', 219),
#    ('Political history of India', 207),
#    ('British East India Company', 195)],
#   'top_categorias_ocultas': [('All Wikipedia articles written in Indian English',
#     7385),
#    ('All articles with unsourced statements', 4247),
#    ('Webarchive template wayback links', 3030),
#    ('All articles needing additional references', 2918),
#    ('Coordinates on Wikidata', 1836),
#    ('All articles with dead external links', 1814),
#    ('Wikipedia articles with GND identifiers', 1299),
#    ('Wikipedia articles with VIAF identifiers', 1260),
#    ('Articles with permanently dead external links', 1202),
#    ('Articles with hAudio microformats', 1164),
#    ('All articles containing potentially dated statements', 1002),
#    ('Wikipedia articles with LCCN identifiers', 882),
#    ('Use Indian English from June 2016', 849),
#    ('Use dmy dates from March 2013', 800),
#    ('All articles lacking reliable references', 772),
#    ('Articles with hCards', 763),
#    ('Wikipedia articles with BNF identifiers', 746),
#    ('Wikipedia indefinitely semi-protected pages', 706),
#    ('CS1 maint: Extra text: authors list', 690),
#    ('Wikipedia articles with ISNI identifiers', 680)]},
#  8: {'top_categorias': [('Windows games', 842),
#    ('Xbox One games', 649),
#    ('PlayStation 4 games', 544),
#    ('Manga series', 514),
#    ('Xbox 360 games', 462),
#    ('Multiplayer and single-player video games', 376),
#    ('Video games developed in the United States', 373),
#    ('Funimation', 360),
#    ('Open world video games', 342),
#    ('MacOS games', 319),
#    ('PlayStation 3 games', 314),
#    ('ShÅ\x8dnen manga', 312),
#    ('Action-adventure games', 309),
#    ('Lists of anime episodes', 275),
#    ('American inventions', 269),
#    ('IOS games', 266),
#    ('Single-player video games', 259),
#    ('Dragon Ball episode lists', 244),
#    ('Video games developed in Japan', 237),
#    ('IOS (Apple)', 235)],
#   'top_categorias_ocultas': [('All articles with unsourced statements', 4418),
#    ('Articles containing Japanese-language text', 2148),
#    ('All articles needing additional references', 2119),
#    ('Webarchive template wayback links', 1871),
#    ('CS1 Japanese-language sources (ja)', 1773),
#    ('All articles containing potentially dated statements', 1427),
#    ('Wikipedia articles with GND identifiers', 1228),
#    ('Official website different in Wikidata and Wikipedia', 1156),
#    ('Articles using Infobox video game using locally defined parameters',
#     1152),
#    ('Articles using Wikidata infoboxes with locally defined images', 1135),
#    ('CS1 uses Japanese-language script (ja)', 1084),
#    ('All articles with dead external links', 1030),
#    ('Pages using deprecated image syntax', 967),
#    ('Articles with Japanese-language external links', 821),
#    ('Articles using Video game reviews template in single platform mode', 793),
#    ('Articles with permanently dead external links', 661),
#    ('Articles using small message boxes', 584),
#    ('Wikipedia articles with LCCN identifiers', 573),
#    ('All articles to be expanded', 558),
#    ('Pages using RFC magic links', 548)]},
#  9: {'top_categorias': [('Business terms', 184),
#    ('Production economics', 131),
#    ('Contract law', 126),
#    ('Legal doctrines and principles', 121),
#    ('Sociological theories', 113),
#    ('Criminal law', 112),
#    ('Sociological terminology', 109),
#    ('Capitalism', 107),
#    ('Accounting terminology', 103),
#    ('Legal terminology', 101),
#    ('Philosophy of science', 99),
#    ('Educational psychology', 98),
#    ('Scientific method', 92),
#    ('Criminal procedure', 90),
#    ('Economic systems', 89),
#    ('Business law', 89),
#    ('Political philosophy', 85),
#    ('Latin legal terminology', 84),
#    ('English phrases', 84),
#    ('Design of experiments', 83)],
#   'top_categorias_ocultas': [('All articles with unsourced statements', 4581),
#    ('All articles needing additional references', 2227),
#    ('Webarchive template wayback links', 2077),
#    ('Wikipedia articles with GND identifiers', 2048),
#    ('All articles with dead external links', 1074),
#    ('CS1 maint: Multiple names: authors list', 806),
#    ('All articles with specifically marked weasel-worded phrases', 758),
#    ('Wikipedia articles with LCCN identifiers', 726),
#    ('Articles with permanently dead external links', 683),
#    ('Wikipedia articles with NDL identifiers', 572),
#    ('Articles with multiple maintenance issues', 492),
#    ('Wikipedia articles with BNF identifiers', 482),
#    ('All articles to be expanded', 456),
#    ('Articles using small message boxes', 448),
#    ('CS1 maint: Extra text: authors list', 395),
#    ('All pages needing cleanup', 380),
#    ('All articles that may contain original research', 374),
#    ('Pages using citations with accessdate and no URL', 372),
#    ('All stub articles', 359),
#    ('All articles lacking in-text citations', 358)]},
#  10: {'top_categorias': [('Living people', 1263),
#    ('National Basketball Association lists', 894),
#    ('National Football League teams', 882),
#    ('Lists of sports championships', 433),
#    ('Major League Baseball teams', 408),
#    ('Major League Baseball lists', 407),
#    ('National Basketball Association statistical leaders', 390),
#    ('Super Bowl', 388),
#    ('African-American basketball players', 383),
#    ('Annual sporting events in the United States', 345),
#    ('National Basketball Association All-Stars', 315),
#    ('World Series', 300),
#    ('United States men&#39;s national basketball team players', 286),
#    ('Parade High School All-Americans (boys&#39; basketball)', 279),
#    ('Super Bowl lists', 277),
#    ('National Basketball Association teams', 266),
#    ('Sports clubs established in 1960', 266),
#    ('McDonald&#39;s High School All-Americans', 265),
#    ('American football quarterbacks', 259),
#    ('Olympic gold medalists for the United States in basketball', 257)],
#   'top_categorias_ocultas': [('All articles with unsourced statements', 4465),
#    ('Webarchive template wayback links', 3671),
#    ('Articles with hCards', 3082),
#    ('All articles with dead external links', 2838),
#    ('All articles needing additional references', 2543),
#    ('Articles with permanently dead external links', 1694),
#    ('Wikipedia articles with VIAF identifiers', 1275),
#    ('Wikipedia articles with LCCN identifiers', 1241),
#    ('Featured lists', 1212),
#    ('Pages using deprecated image syntax', 1054),
#    ('All articles containing potentially dated statements', 883),
#    ('Coordinates on Wikidata', 823),
#    ('Wikipedia indefinitely semi-protected pages', 805),
#    ('Wikipedia pages semi-protected against vandalism', 750),
#    ('Good articles', 663),
#    ('Wikipedia articles with GND identifiers', 615),
#    ('Pages using citations with accessdate and no URL', 600),
#    ('Pages with citations lacking titles', 600),
#    ('Official website different in Wikidata and Wikipedia', 595),
#    ('Pages containing links to subscription-only content', 592)]},
#  11: {'top_categorias': [('Surnames', 601),
#    ('Countries at the FIFA World Cup', 522),
#    ('2018 FIFA World Cup', 515),
#    ('FIFA World Cup tournaments', 458),
#    ('Living people', 455),
#    ('FIFA World Cup-related lists', 388),
#    ('Association football records and statistics', 350),
#    ('FIFA World Cup statistics', 255),
#    ('Association football forwards', 245),
#    ('Premier League players', 236),
#    ('British monarchy', 230),
#    ('La Liga players', 224),
#    ('History of the England national football team', 216),
#    ('2018 in association football', 213),
#    ('International association football competitions hosted by Russia', 212),
#    ('UEFA Champions League winning players', 207),
#    ('July 2018 sports events in Europe', 206),
#    ('June 2018 sports events in Europe', 205),
#    ('England at the FIFA World Cup', 204),
#    ('Football clubs in England', 204)],
#   'top_categorias_ocultas': [('All articles with unsourced statements', 3325),
#    ('Webarchive template wayback links', 2846),
#    ('All articles needing additional references', 1910),
#    ('All articles with dead external links', 1745),
#    ('Wikipedia articles with GND identifiers', 1402),
#    ('Articles with permanently dead external links', 1272),
#    ('Wikipedia articles with VIAF identifiers', 1226),
#    ('Coordinates on Wikidata', 1116),
#    ('Articles with hCards', 1079),
#    ('Wikipedia articles with LCCN identifiers', 1025),
#    ('CS1 Spanish-language sources (es)', 960),
#    ('Pages using deprecated image syntax', 867),
#    ('All articles containing potentially dated statements', 724),
#    ('All set index articles', 640),
#    ('Pages containing links to subscription-only content', 632),
#    ('Featured articles', 625),
#    ('Wikipedia articles with ISNI identifiers', 615),
#    ('Wikipedia articles with BNF identifiers', 610),
#    ('Articles with short description', 581),
#    ('CS1 Italian-language sources (it)', 569)]},
#  12: {'top_categorias': [('Fast-food chains of the United States', 268),
#    ('Fast-food franchises', 194),
#    ('Las Vegas Strip', 169),
#    ('RMS Titanic', 133),
#    ('Restaurant chains in the United States', 131),
#    ('Skyscraper hotels in Paradise, Nevada', 102),
#    ('1912 in Canada', 99),
#    ('1912 in the United Kingdom', 99),
#    ('1912 in the United States', 99),
#    ('Casino hotels', 98),
#    ('Casinos in the Las Vegas Valley', 94),
#    ('Resorts in the Las Vegas Valley', 93),
#    ('Fast-food hamburger restaurants', 88),
#    ('Maritime incidents in 1912', 83),
#    ('Regional restaurant chains in the United States', 81),
#    ('1910s in Newfoundland', 80),
#    ('Ship collisions with icebergs', 80),
#    ('Ships sunk in collisions', 79),
#    ('1911 ships', 78),
#    ('History of Halifax, Nova Scotia', 78)],
#   'top_categorias_ocultas': [('All articles with unsourced statements', 585),
#    ('All articles needing additional references', 301),
#    ('Webarchive template wayback links', 294),
#    ('Coordinates on Wikidata', 288),
#    ('Pages using deprecated image syntax', 264),
#    ('All articles with dead external links', 211),
#    ('All articles containing potentially dated statements', 186),
#    ('Wikipedia articles with LCCN identifiers', 180),
#    ('Wikipedia articles with VIAF identifiers', 179),
#    ('Pages containing links to subscription-only content', 164),
#    ('Official website different in Wikidata and Wikipedia', 163),
#    ('Wikipedia articles with GND identifiers', 134),
#    ('Pages using citations with accessdate and no URL', 131),
#    ('Wikipedia indefinitely semi-protected pages', 119),
#    ('Wikipedia indefinitely move-protected pages', 104),
#    ('CS1 maint: BOT: original-url status unknown', 91),
#    ('Articles with hAudio microformats', 89),
#    ('Articles with permanently dead external links', 84),
#    ('Good articles', 73),
#    ('Wikipedia articles with SNAC-ID identifiers', 71)]},
#  13: {'top_categorias': [('The Office (U.S. TV series) characters', 151),
#    ('Fictional characters introduced in 2005', 122),
#    ('The Office (U.S. TV series) episodes in multiple parts', 70),
#    ('Fictional American people of English descent', 61),
#    ('Fictional receptionists', 56),
#    ('Fictional secretaries', 50),
#    ('2009 American television episodes', 47),
#    ('The Office (U.S. season 9) episodes', 46),
#    ('2007 American television episodes', 43),
#    ('The Office (U.S. season 3) episodes', 38),
#    ('The Office (U.S. season 5) episodes', 34),
#    ('The Office (U.S. season 6) episodes', 33),
#    ('The Office (U.S. season 8) episodes', 28),
#    ('Television episodes about weddings', 28),
#    ('2013 American television episodes', 27),
#    ('Fictional salespeople', 27),
#    ('Fictional American people of Scottish descent', 27),
#    ('2012 American television seasons', 25),
#    ('2011 American television episodes', 24),
#    ('The Office (U.S. season 2) episodes', 21)],
#   'top_categorias_ocultas': [('Good articles', 180),
#    ('Tv.com template using numeric id', 113),
#    ('All articles that need to differentiate between fact and fiction', 93),
#    ('All articles with dead external links', 70),
#    ('Articles that need to differentiate between fact and fiction from December 2015',
#     69),
#    ('Webarchive template wayback links', 67),
#    ('Use mdy dates from January 2018', 60),
#    ('All articles needing additional references', 59),
#    ('Pages using deprecated image syntax', 59),
#    ('TV.com template using numeric id', 58),
#    ('Articles needing additional references from November 2012', 50),
#    ('Articles with multiple maintenance issues', 47),
#    ('Articles with permanently dead external links', 42),
#    ('Pages using infobox character with unknown parameters', 37),
#    ('Pages containing links to subscription-only content', 34),
#    ('Articles with short description', 31),
#    ('Featured lists', 25),
#    ('Television episode articles with short description for single episodes',
#     24),
#    ('All articles lacking reliable references', 20),
#    ('Articles with dead external links from June 2017', 20)]},
#  14: {'top_categorias': [('Days of Our Lives characters', 203),
#    ('Living people', 44),
#    ('Days of Our Lives', 38),
#    ('Fictional American people of Irish descent', 29),
#    ('Fictional American people of English descent', 29),
#    ('Lists of actors by soap opera television series', 26),
#    ('American soap opera actresses', 25),
#    ('Fictional businesspeople', 18),
#    ('American television actresses', 18),
#    ('Fictional lawyers', 17),
#    ('Fictional murderers', 16),
#    ('Fictional characters introduced in 1996', 16),
#    ('American male soap opera actors', 16),
#    ('Fictional rapists', 16),
#    ('Fictional gay males', 15),
#    ('Fictional LGBT characters in television', 15),
#    ('Fictional African-American people', 15),
#    ('Fictional characters introduced in 1982', 14),
#    ('Fictional sexual assault victims', 13),
#    ('Fictional American police officers', 13)],
#   'top_categorias_ocultas': [('Pages using citations with accessdate and no URL',
#     57),
#    ('Articles with multiple maintenance issues', 48),
#    ('Articles with hCards', 44),
#    ('All articles that need to differentiate between fact and fiction', 43),
#    ('All articles needing additional references', 34),
#    ('Wikipedia articles with incorrect tenses', 25),
#    ('Wikipedia pages semi-protected against vandalism', 25),
#    ('All articles with dead external links', 25),
#    ('All articles with unsourced statements', 24),
#    ('All articles to be expanded', 22),
#    ('All articles lacking sources', 21),
#    ('All BLP articles lacking sources', 19),
#    ('All Wikipedia articles with plot summary needing attention', 18),
#    ('Articles with permanently dead external links', 13),
#    ('Articles that need to differentiate between fact and fiction from January 2010',
#     12),
#    ('CS1 French-language sources (fr)', 12),
#    ('Pages with citations having bare URLs', 12),
#    ('Articles with unsourced statements from September 2017', 11),
#    ('Pages with citations lacking titles', 11),
#    ('Pages using web citations with no URL', 10)]},
#  15: {'top_categorias': [('Roud Folk Song Index songs', 271),
#    ('English nursery rhymes', 254),
#    ('Children&#39;s songs', 158),
#    ('Year of song unknown', 132),
#    ('Songwriter unknown', 114),
#    ('Singing games', 99),
#    ('Lullabies', 46),
#    ('American nursery rhymes', 44),
#    ('English folk songs', 43),
#    ('1790s in England', 42),
#    ('1881 songs', 42),
#    ('1881 in England', 42),
#    ('Urban legends', 42),
#    ('English folklore', 33),
#    ('Songs about London', 33),
#    ('Riddles', 30),
#    ('Nursery rhymes', 29),
#    ('Songs about children', 28),
#    ('Music education', 27),
#    ('Songs about women', 27)],
#   'top_categorias_ocultas': [('Articles with hAudio microformats', 166),
#    ('Good articles', 106),
#    ('All articles with unsourced statements', 91),
#    ('All articles needing additional references', 63),
#    ('CS1 maint: Extra text: authors list', 49),
#    ('CS1: Julianâ\x80\x93Gregorian uncertainty', 39),
#    ('All articles lacking reliable references', 37),
#    ('Webarchive template wayback links', 29),
#    ('All articles with dead external links', 24),
#    ('Articles with dead external links from July 2017', 22),
#    ('Use dmy dates from January 2015', 22),
#    ('Articles containing potentially dated statements from April 2008', 22),
#    ('All articles containing potentially dated statements', 22),
#    ('Articles lacking reliable references from May 2015', 22),
#    ('Use dmy dates from July 2012', 18),
#    ('Commons category with page title different than on Wikidata', 18),
#    ('Articles with trivia sections from March 2017', 14),
#    ('All articles with trivia sections', 14),
#    ('Articles with unsourced statements from December 2017', 12),
#    ('Articles with unsourced statements from July 2012', 12)]},
#  16: {'top_categorias': [('Coronation Street characters', 71),
#    ('Fictional bartenders', 26),
#    ('Fictional businesspeople', 23),
#    ('Fictional victims of kidnapping', 16),
#    ('Fictional British people', 16),
#    ('Lists of Coronation Street characters', 15),
#    ('Living people', 13),
#    ('Coronation Street', 13),
#    ('Fictional English people of Irish descent', 13),
#    ('Fictional English people', 12),
#    ('Fictional factory workers', 11),
#    ('Fictional British people of Irish descent', 11),
#    ('Fictional characters introduced in 2006', 10),
#    ('Fictional twins', 9),
#    ('Fictional taxicab drivers', 9),
#    ('Fictional domestic abusers', 8),
#    ('Fictional waiting staff', 7),
#    ('English television actresses', 7),
#    ('Female characters in television', 7),
#    ('Fictional teenage parents', 7)],
#   'top_categorias_ocultas': [('Use British English from March 2014', 38),
#    ('Use dmy dates from March 2014', 28),
#    ('Pages using deprecated image syntax', 22),
#    ('All articles with unsourced statements', 16),
#    ('Articles with hCards', 12),
#    ('All articles with dead external links', 11),
#    ('Pages using citations with accessdate and no URL', 11),
#    ('Use dmy dates from October 2013', 10),
#    ('CS1 maint: Extra text: authors list', 10),
#    ('Use dmy dates from March 2011', 9),
#    ('Wikipedia semi-protected pages', 8),
#    ('EngvarB from November 2017', 7),
#    ('Use dmy dates from November 2017', 7),
#    ('EngvarB from October 2013', 7),
#    ('All articles that need to differentiate between fact and fiction', 7),
#    ('Use British English from June 2016', 7),
#    ('All articles needing additional references', 7),
#    ('Use dmy dates from July 2018', 6),
#    ('Articles that need to differentiate between fact and fiction from December 2013',
#     6),
#    ('Wikipedia articles needing clarification from October 2016', 6)]},
#  17: {'top_categorias': [('United States gun laws by state', 332),
#    ('Texas law', 48),
#    ('Gun politics in the United States', 45),
#    ('Self-defense', 44),
#    ('United States firearms law', 29),
#    ('Licenses', 28),
#    ('Michigan law', 21),
#    ('Indiana law', 18),
#    ('Homicide', 16),
#    ('Legal doctrines and principles', 16),
#    ('U.S. state criminal law', 16),
#    ('Controversies in the United States', 16),
#    ('New York (state) law', 16),
#    ('Virginia law', 14),
#    ('Florida law', 13),
#    ('California law', 12),
#    ('North Carolina law', 12),
#    ('Missouri law', 10),
#    ('Washington (state) law', 10),
#    ('Colorado law', 10)],
#   'top_categorias_ocultas': [('All articles with unsourced statements', 103),
#    ('Webarchive template wayback links', 79),
#    ('Pages with citations lacking titles', 62),
#    ('Pages with citations having bare URLs', 62),
#    ('All articles lacking reliable references', 42),
#    ('Articles with unsourced statements from June 2016', 36),
#    ('All articles containing potentially dated statements', 35),
#    ('All articles needing additional references', 35),
#    ('Pages using web citations with no URL', 27),
#    ('Articles with unsourced statements from December 2010', 26),
#    ('Articles with unsourced statements from August 2017', 22),
#    ('Use mdy dates from February 2014', 21),
#    ('Articles lacking reliable references from December 2015', 21),
#    ('CS1 errors: external links', 19),
#    ('All articles with dead external links', 18),
#    ('Articles with unsourced statements from March 2015', 18),
#    ('Articles with unsourced statements from March 2016', 18),
#    ('Articles with unsourced statements from February 2015', 18),
#    ('Articles with unsourced statements from August 2013', 18),
#    ('Articles with unsourced statements from September 2013', 18)]},
#  18: {'top_categorias': [('Home and Away characters', 63),
#    ('Lists of Home and Away characters', 47),
#    ('Fictional characters introduced in 1988', 29),
#    ('Fictional businesspeople', 19),
#    ('Fictional teenage parents', 15),
#    ('Fictional waiting staff', 14),
#    ('Lists of actors by soap opera television series', 14),
#    ('Fictional people from New South Wales', 13),
#    ('Fictional characters introduced in 2015', 11),
#    ('Fictional characters introduced in 2017', 10),
#    ('2017 in Australian television', 10),
#    ('Fictional shopkeepers', 10),
#    ('Fictional schoolteachers', 9),
#    ('Fictional victims of kidnapping', 8),
#    ('Fictional characters introduced in 1989', 7),
#    ('Fictional murderers', 7),
#    ('Fictional characters introduced in 2013', 7),
#    ('Living people', 7),
#    ('Fictional characters introduced in 2018', 7),
#    ('2018 in Australian television', 7)],
#   'top_categorias_ocultas': [('Pages using deprecated image syntax', 44),
#    ('All Wikipedia articles written in Australian English', 32),
#    ('Pages using citations with accessdate and no URL', 32),
#    ('Articles with attributed pull quotes', 29),
#    ('Pages containing links to subscription-only content', 22),
#    ('Articles with hCards', 21),
#    ('Use dmy dates from July 2017', 17),
#    ('Use Australian English from July 2017', 17),
#    ('Use dmy dates from October 2013', 15),
#    ('EngvarB from October 2013', 13),
#    ('EngvarB from November 2017', 9),
#    ('Use dmy dates from November 2017', 9),
#    ('Pages with reference errors', 8),
#    ('Pages with duplicate reference names', 8),
#    ('Pages using citations with format and no URL', 4),
#    ('Good articles', 4),
#    ('Use dmy dates from November 2012', 4),
#    ('All stub articles', 4),
#    ('Use dmy dates from January 2013', 4),
#    ('Use Australian English from January 2013', 4)]}}

# %%
def make_prompt(category_llm, top_categories):
    top_cats_str = ", ".join([cat for cat, _ in top_categories])
    prompt = f"""
You are an accurate semantic evaluator. Evaluate the relevance of the following category created by an LLM model relative to a community's top keywords.

LLM-generated category: "{category_llm}"
Top keywords from the community: "{top_cats_str}"

Your task is to provide a single floating-point number between 0.0 and 1.0, where:
- 0.0 = no semantic relationship
- 0.3 = weak/tangential relationship
- 0.5 = moderate relationship
- 0.7 = strong relationship
- 1.0 = perfect semantic match

Return ONLY the number, nothing else.

"""
    return prompt

# %%
def evaluate_correlation(category_llm, top_categories):
    prompt = make_prompt(category_llm, top_categories)
    url = "http://localhost:11434/api/generate"
    data = {
        "model": "mistral",
        "prompt": prompt,
        "stream": False,
        "options": {
            "seed": 42,
            "top_k": 1,
            "top_p": 1,
            "temperature": 0
        }
    }

    url = "http://localhost:11434/api/generate"
    headers = {"Content-Type": "application/json"}

    try:
        resp = requests.post(url, headers=headers, json=data, timeout=3000)
        resp.raise_for_status()
        result = resp.json()
        return result.get("response", "").strip().lower()
    except Exception as e:
        print(f"Erro ao categorizar: {e}")
        return "erro"

# %%
import pandas as pd

scores = []

for idx, row in df.iterrows():
    community_id = row['community_id']
    category_llm = row['category']
    top_categories = top20_per_community_wiki.get(community_id, {}).get('top_categorias', [])
    print(f"Evaluating community {community_id} with LLM category '{category_llm}' and top categories {top_categories}")
# Out:
# Evaluating community 0 with LLM category 'film & tv content; actors & characters' and top categories [('English-language films', 16201), ('American films', 14439), ('English-language television programs', 9363), ('Living people', 7636), ('IMAX films', 3116), ('American male film actors', 2877), ('American male television actors', 2833), ('American sequel films', 2627), ('American television actresses', 2608), ('American film actresses', 2503), ('2010s American drama television series', 2402), ('2017 films', 2221), ('21st-century American actresses', 2194), ('Films featuring anthropomorphic characters', 2160), ('21st-century American male actors', 2101), ('20th-century American male actors', 2098), ('2017 American television seasons', 1994), ('2010s American television series', 1989), ('British films', 1931), ('20th-century American actresses', 1890)]
# Evaluating community 1 with LLM category 'music & albums; love songs' and top categories [('Billboard Hot 100 number-one singles', 3932), ('UK Singles Chart number-one singles', 3507), ('Number-one singles in Australia', 2693), ('Irish Singles Chart number-one singles', 2406), ('RPM Top Singles number-one singles', 2318), ('Billboard Adult Contemporary number-one singles', 2296), ('Pop ballads', 2128), ('Columbia Records singles', 2020), ('Number-one singles in New Zealand', 1960), ('Debut singles', 1653), ('Number-one singles in Norway', 1607), ('Billboard Hot R&amp;B/Hip-Hop Songs number-one singles', 1500), ('Billboard Hot Country Songs number-one singles', 1474), ('Rock ballads', 1459), ('Dutch Top 40 number-one singles', 1379), ('Number-one singles in Germany', 1366), ('European Hot 100 Singles number-one singles', 1312), ('Number-one singles in Sweden', 1304), ('Number-one singles in Switzerland', 1280), ('Living people', 1214)]
# Evaluating community 2 with LLM category 'global affairs; geography; sports & competitions' and top categories [('Member states of the United Nations', 678), ('Visa requirements by nationality', 512), ('Living people', 429), ('Lists of countries', 400), ('English-speaking countries and territories', 324), ('Minimum ages', 315), ('Republics', 293), ('Wars involving the United States', 287), ('Wars involving the United Kingdom', 267), ('Law-related lists', 249), ('Lists by country', 245), ('National flags', 241), ('World War I', 234), ('Wars involving France', 233), ('Soviet Unionâ\x80\x93United States relations', 232), ('Traffic law', 230), ('Global conflicts', 226), ('Member states of the Commonwealth of Nations', 226), ('Proxy wars', 219), ('Visa policy by country', 216)]
# Evaluating community 3 with LLM category 'united states history; american states; national & state affairs' and top categories [('Legal history of the United States', 624), ('History of United States expansionism', 579), ('Amendments to the United States Constitution', 562), ('States of the United States', 491), ('Wars involving the United States', 486), ('History of the United States (1865â\x80\x931918)', 480), ('1789 establishments in the United States', 454), ('History of the United States (1776â\x80\x9389)', 441), ('United States Supreme Court cases', 434), ('American Revolution', 433), ('Historic Civil Engineering Landmarks', 416), ('History of the United States (1789â\x80\x931849)', 394), ('United States historical documents', 383), ('National symbols of the United States', 379), ('Legislative branch of the United States government', 352), ('Official documents of the United States', 332), ('Colonization history of the United States', 326), ('Progressive Era in the United States', 323), ('United States Declaration of Independence', 321), ('Clauses of the United States Constitution', 318)]
# Evaluating community 4 with LLM category 'medical history; american cuisine; human health' and top categories [('Wikipedia articles incorporating text from the 20th edition of Gray&#39;s Anatomy (1918)', 453), ('Metabolism', 403), ('IUCN Red List least concern species', 381), ('Cellular respiration', 366), ('Digestive system', 339), ('Plant physiology', 300), ('Cell biology', 270), ('Molecular biology', 250), ('Photosynthesis', 248), ('Plate tectonics', 244), ('Membrane biology', 236), ('Skeletal system', 223), ('Organs (anatomy)', 204), ('Taxa named by Carl Linnaeus', 200), ('Oceanographical terminology', 199), ('Nutrition', 197), ('Cell anatomy', 193), ('Genetics', 189), ('Organelles', 185), ('Cardiac anatomy', 181)]
# Evaluating community 5 with LLM category 'power systems; energy sources; historical vehicles' and top categories [('All-wheel-drive vehicles', 475), ('2000s automobiles', 457), ('2010s automobiles', 452), ('Rear-wheel-drive vehicles', 362), ('Front-wheel-drive vehicles', 329), ('Motor vehicles manufactured in the United States', 303), ('1990s automobiles', 268), ('Concepts in physics', 265), ('Chemical elements', 228), ('Physical quantities', 222), ('CoupÃ©s', 211), ('American inventions', 207), ('Periodic table', 189), ('Sedans', 185), ('Hatchbacks', 165), ('Chemical properties', 164), ('Chemical bonding', 156), ('1980s automobiles', 155), ('Units of time', 153), ('Crossover sport utility vehicles', 151)]
# Evaluating community 6 with LLM category 'ancient roman art & religion; catholic history & empire' and top categories [('Christian terminology', 1130), ('Biblical phrases', 383), ('Former empires', 245), ('Former countries in Europe', 242), ('Former countries in Asia', 206), ('English-language idioms', 186), ('New Testament books', 179), ('Former countries in Africa', 178), ('Islamic terminology', 171), ('Chinese architectural history', 170), ('Great Wall of China', 166), ('French Revolution', 148), ('Hebrew Bible words and phrases', 142), ('Cultural lists', 138), ('Book of Genesis', 136), ('American films', 132), ('Historical eras', 132), ('English-language films', 131), ('Canonical epistles', 130), ('1789 events of the French Revolution', 130)]
# Evaluating community 7 with LLM category 'sports & culture; south asia; education & technology' and top categories [('Indian films', 833), ('Living people', 423), ('Hindi-language films', 346), ('Constitution of India', 341), ('Hindi-language television programs', 320), ('Parliament of India', 293), ('History of Bengal', 285), ('History of Pakistan', 284), ('Independent India', 280), ('2010s Indian television series', 277), ('History of West Bengal', 276), ('Indian independence movement', 261), ('Indian drama television series', 255), ('2010s Hindi-language films', 248), ('History of Kolkata', 240), ('Indian reality television series', 226), ('History of Bangladesh', 225), ('Star Plus television series', 219), ('Political history of India', 207), ('British East India Company', 195)]
# Evaluating community 8 with LLM category 'computer games history; video game software; network systems data' and top categories [('Windows games', 842), ('Xbox One games', 649), ('PlayStation 4 games', 544), ('Manga series', 514), ('Xbox 360 games', 462), ('Multiplayer and single-player video games', 376), ('Video games developed in the United States', 373), ('Funimation', 360), ('Open world video games', 342), ('MacOS games', 319), ('PlayStation 3 games', 314), ('ShÅ\x8dnen manga', 312), ('Action-adventure games', 309), ('Lists of anime episodes', 275), ('American inventions', 269), ('IOS games', 266), ('Single-player video games', 259), ('Dragon Ball episode lists', 244), ('Video games developed in Japan', 237), ('IOS (Apple)', 235)]
# Evaluating community 9 with LLM category 'legal & social studies; management & market analysis; psychology & taxation models' and top categories [('Business terms', 184), ('Production economics', 131), ('Contract law', 126), ('Legal doctrines and principles', 121), ('Sociological theories', 113), ('Criminal law', 112), ('Sociological terminology', 109), ('Capitalism', 107), ('Accounting terminology', 103), ('Legal terminology', 101), ('Philosophy of science', 99), ('Educational psychology', 98), ('Scientific method', 92), ('Criminal procedure', 90), ('Economic systems', 89), ('Business law', 89), ('Political philosophy', 85), ('Latin legal terminology', 84), ('English phrases', 84), ('Design of experiments', 83)]
# Evaluating community 10 with LLM category 'sports competitions; american team sports; seasons' and top categories [('Living people', 1263), ('National Basketball Association lists', 894), ('National Football League teams', 882), ('Lists of sports championships', 433), ('Major League Baseball teams', 408), ('Major League Baseball lists', 407), ('National Basketball Association statistical leaders', 390), ('Super Bowl', 388), ('African-American basketball players', 383), ('Annual sporting events in the United States', 345), ('National Basketball Association All-Stars', 315), ('World Series', 300), ('United States men&#39;s national basketball team players', 286), ('Parade High School All-Americans (boys&#39; basketball)', 279), ('Super Bowl lists', 277), ('National Basketball Association teams', 266), ('Sports clubs established in 1960', 266), ('McDonald&#39;s High School All-Americans', 265), ('American football quarterbacks', 259), ('Olympic gold medalists for the United States in basketball', 257)]
# Evaluating community 11 with LLM category 'football community; united kingdom; fifa matters' and top categories [('Surnames', 601), ('Countries at the FIFA World Cup', 522), ('2018 FIFA World Cup', 515), ('FIFA World Cup tournaments', 458), ('Living people', 455), ('FIFA World Cup-related lists', 388), ('Association football records and statistics', 350), ('FIFA World Cup statistics', 255), ('Association football forwards', 245), ('Premier League players', 236), ('British monarchy', 230), ('La Liga players', 224), ('History of the England national football team', 216), ('2018 in association football', 213), ('International association football competitions hosted by Russia', 212), ('UEFA Champions League winning players', 207), ('July 2018 sports events in Europe', 206), ('June 2018 sports events in Europe', 205), ('England at the FIFA World Cup', 204), ('Football clubs in England', 204)]
# Evaluating community 12 with LLM category 'gambling & entertainment; las vegas; maritime' and top categories [('Fast-food chains of the United States', 268), ('Fast-food franchises', 194), ('Las Vegas Strip', 169), ('RMS Titanic', 133), ('Restaurant chains in the United States', 131), ('Skyscraper hotels in Paradise, Nevada', 102), ('1912 in Canada', 99), ('1912 in the United Kingdom', 99), ('1912 in the United States', 99), ('Casino hotels', 98), ('Casinos in the Las Vegas Valley', 94), ('Resorts in the Las Vegas Valley', 93), ('Fast-food hamburger restaurants', 88), ('Maritime incidents in 1912', 83), ('Regional restaurant chains in the United States', 81), ('1910s in Newfoundland', 80), ('Ship collisions with icebergs', 80), ('Ships sunk in collisions', 79), ('1911 ships', 78), ('History of Halifax, Nova Scotia', 78)]
# Evaluating community 13 with LLM category 'office workers; tv series characters' and top categories [('The Office (U.S. TV series) characters', 151), ('Fictional characters introduced in 2005', 122), ('The Office (U.S. TV series) episodes in multiple parts', 70), ('Fictional American people of English descent', 61), ('Fictional receptionists', 56), ('Fictional secretaries', 50), ('2009 American television episodes', 47), ('The Office (U.S. season 9) episodes', 46), ('2007 American television episodes', 43), ('The Office (U.S. season 3) episodes', 38), ('The Office (U.S. season 5) episodes', 34), ('The Office (U.S. season 6) episodes', 33), ('The Office (U.S. season 8) episodes', 28), ('Television episodes about weddings', 28), ('2013 American television episodes', 27), ('Fictional salespeople', 27), ('Fictional American people of Scottish descent', 27), ('2012 American television seasons', 25), ('2011 American television episodes', 24), ('The Office (U.S. season 2) episodes', 21)]
# Evaluating community 14 with LLM category '"days of our lives characters"; "horton-dimera family"; "kiriakis-carver connection"' and top categories [('Days of Our Lives characters', 203), ('Living people', 44), ('Days of Our Lives', 38), ('Fictional American people of Irish descent', 29), ('Fictional American people of English descent', 29), ('Lists of actors by soap opera television series', 26), ('American soap opera actresses', 25), ('Fictional businesspeople', 18), ('American television actresses', 18), ('Fictional lawyers', 17), ('Fictional murderers', 16), ('Fictional characters introduced in 1996', 16), ('American male soap opera actors', 16), ('Fictional rapists', 16), ('Fictional gay males', 15), ('Fictional LGBT characters in television', 15), ('Fictional African-American people', 15), ('Fictional characters introduced in 1982', 14), ('Fictional sexual assault victims', 13), ('Fictional American police officers', 13)]
# Evaluating community 15 with LLM category '"baby animals; weather; miscellaneous"' and top categories [('Roud Folk Song Index songs', 271), ('English nursery rhymes', 254), ('Children&#39;s songs', 158), ('Year of song unknown', 132), ('Songwriter unknown', 114), ('Singing games', 99), ('Lullabies', 46), ('American nursery rhymes', 44), ('English folk songs', 43), ('1790s in England', 42), ('1881 songs', 42), ('1881 in England', 42), ('Urban legends', 42), ('English folklore', 33), ('Songs about London', 33), ('Riddles', 30), ('Nursery rhymes', 29), ('Songs about children', 28), ('Music education', 27), ('Songs about women', 27)]
# Evaluating community 16 with LLM category 'coronation street characters; british soap opera cast' and top categories [('Coronation Street characters', 71), ('Fictional bartenders', 26), ('Fictional businesspeople', 23), ('Fictional victims of kidnapping', 16), ('Fictional British people', 16), ('Lists of Coronation Street characters', 15), ('Living people', 13), ('Coronation Street', 13), ('Fictional English people of Irish descent', 13), ('Fictional English people', 12), ('Fictional factory workers', 11), ('Fictional British people of Irish descent', 11), ('Fictional characters introduced in 2006', 10), ('Fictional twins', 9), ('Fictional taxicab drivers', 9), ('Fictional domestic abusers', 8), ('Fictional waiting staff', 7), ('English television actresses', 7), ('Female characters in television', 7), ('Fictional teenage parents', 7)]
# Evaluating community 17 with LLM category 'gun laws in us states; concealed carry regulations (california, virginia, carolina)' and top categories [('United States gun laws by state', 332), ('Texas law', 48), ('Gun politics in the United States', 45), ('Self-defense', 44), ('United States firearms law', 29), ('Licenses', 28), ('Michigan law', 21), ('Indiana law', 18), ('Homicide', 16), ('Legal doctrines and principles', 16), ('U.S. state criminal law', 16), ('Controversies in the United States', 16), ('New York (state) law', 16), ('Virginia law', 14), ('Florida law', 13), ('California law', 12), ('North Carolina law', 12), ('Missouri law', 10), ('Washington (state) law', 10), ('Colorado law', 10)]
# Evaluating community 18 with LLM category 'characters at home; workplace characters' and top categories [('Home and Away characters', 63), ('Lists of Home and Away characters', 47), ('Fictional characters introduced in 1988', 29), ('Fictional businesspeople', 19), ('Fictional teenage parents', 15), ('Fictional waiting staff', 14), ('Lists of actors by soap opera television series', 14), ('Fictional people from New South Wales', 13), ('Fictional characters introduced in 2015', 11), ('Fictional characters introduced in 2017', 10), ('2017 in Australian television', 10), ('Fictional shopkeepers', 10), ('Fictional schoolteachers', 9), ('Fictional victims of kidnapping', 8), ('Fictional characters introduced in 1989', 7), ('Fictional murderers', 7), ('Fictional characters introduced in 2013', 7), ('Living people', 7), ('Fictional characters introduced in 2018', 7), ('2018 in Australian television', 7)]

# %%
import pandas as pd

scores = []

for idx, row in df.iterrows():
    community_id = row['community_id']
    category_llm = row['category']
    top_categories = top20_per_community_wiki.get(community_id, {}).get('top_categorias', [])
    
    score = evaluate_correlation(category_llm, top_categories)
    scores.append(score)

df['llm_correlation'] = scores

# %%
df
# Out:
#    algorithm  community_id                               comm_name  \
# 0     leiden             0          Film, Series, Season, Episodes
# 1     leiden             1                  Song, You, Love, Album
# 2     leiden             2               World, War, South, United
# 3     leiden             3              States, United, New, State
# 4     leiden             4           Cell, History, Human, Cuisine
# 5     leiden             5           Power, System, Energy, Engine
# 6     leiden             6         History, Church, Roman, Ancient
# 7     leiden             7        India, Indian, Cricket, National
# 8     leiden             8         Episodes, Computer, Video, Game
# 9     leiden             9         Law, Theory, Social, Management
# 10    leiden            10  Football, League, Basketball, Baseball
# 11    leiden            11             Cup, Surname, United, World
# 12    leiden            12                Las, Vegas, Card, Casino
# 13    leiden            13          Office, Season, Paper, Michael
# 14    leiden            14                 Brady, Days, Our, Lives
# 15    leiden            15                 Little, Nyah, Old, Baby
# 16    leiden            16  Coronation, Street, Characters, Barlow
# 17    leiden            17                   Gun, Laws, New, Carry
# 18    leiden            18         Home, Away, Characters, Stewart
#
#                                       keywords_string  num_keywords  \
# 0   film, series, season, episodes, characters, ma...            10
# 1   song, you, love, album, music, don, all, your,...            10
# 2   world, war, south, united, history, olympics, ...            10
# 3   states, united, new, state, act, york, america...            10
# 4   cell, history, human, cuisine, system, disease...            10
# 5   power, system, energy, engine, history, ford, ...            10
# 6   history, church, roman, ancient, art, god, bib...            10
# 7   india, indian, cricket, national, pakistan, in...            10
# 8   episodes, computer, video, game, software, sys...            10
# 9   law, theory, social, management, analysis, his...            10
# 10  football, league, basketball, baseball, season...            10
# 11  cup, surname, united, world, fifa, kingdom, fo...            10
# 12  las, vegas, card, casino, poker, game, titanic...            10
# 13  office, season, paper, michael, day, night, an...            10
# 14  brady, days, our, lives, dimera, characters, h...            10
# 15  little, nyah, old, baby, mary, rain, down, man...            10
# 16  coronation, street, characters, barlow, connor...            10
# 17  gun, laws, new, carry, united, states, califor...            10
# 18  home, away, characters, stewart, braxton, king...            10
#
#                                              category llm_correlation
# 0              film & tv content; actors & characters             0.8
# 1                          music & albums; love songs             0.6
# 2    global affairs; geography; sports & competitions             0.6
# 3   united states history; american states; nation...            0.95
# 4     medical history; american cuisine; human health             0.3
# 5   power systems; energy sources; historical vehi...             0.2
# 6   ancient roman art & religion; catholic history...             0.2
# 7   sports & culture; south asia; education & tech...             0.4
# 8   computer games history; video game software; n...             0.6
# 9   legal & social studies; management & market an...             0.6
# 10  sports competitions; american team sports; sea...             0.9
# 11   football community; united kingdom; fifa matters             0.6
# 12      gambling & entertainment; las vegas; maritime             0.4
# 13               office workers; tv series characters             0.8
# 14  "days of our lives characters"; "horton-dimera...             0.6
# 15             "baby animals; weather; miscellaneous"             0.2
# 16  coronation street characters; british soap ope...             0.9
# 17  gun laws in us states; concealed carry regulat...             0.8
# 18           characters at home; workplace characters             0.6

# %%
df['llm_correlation'] = pd.to_numeric(df['llm_correlation'], errors='coerce')

# %%
df.describe()
# Out:
#        community_id  num_keywords  llm_correlation
# count     19.000000          19.0        19.000000
# mean       9.000000          10.0         0.581579
# std        5.627314           0.0         0.243362
# min        0.000000          10.0         0.200000
# 25%        4.500000          10.0         0.400000
# 50%        9.000000          10.0         0.600000
# 75%       13.500000          10.0         0.800000
# max       18.000000          10.0         0.950000

# %%
threshold = 0.7  # acima disso consideramos que bateu com a Wikipedia

df['llm_match'] = df['llm_correlation'] >= threshold
mean_score = df['llm_correlation'].mean()
top_50_percent = df[df['llm_correlation'] >= df['llm_correlation'].quantile(0.5)]

print(f"Mean LLM Correlation Score: {mean_score}")
print(f"Top 50% Communities based on LLM Correlation:\n{top_50_percent}")
# Out:
# Mean LLM Correlation Score: 0.5815789473684211
# Top 50% Communities based on LLM Correlation:
#    algorithm  community_id                               comm_name  \
# 0     leiden             0          Film, Series, Season, Episodes
# 1     leiden             1                  Song, You, Love, Album
# 2     leiden             2               World, War, South, United
# 3     leiden             3              States, United, New, State
# 8     leiden             8         Episodes, Computer, Video, Game
# 9     leiden             9         Law, Theory, Social, Management
# 10    leiden            10  Football, League, Basketball, Baseball
# 11    leiden            11             Cup, Surname, United, World
# 13    leiden            13          Office, Season, Paper, Michael
# 14    leiden            14                 Brady, Days, Our, Lives
# 16    leiden            16  Coronation, Street, Characters, Barlow
# 17    leiden            17                   Gun, Laws, New, Carry
# 18    leiden            18         Home, Away, Characters, Stewart
#
#                                       keywords_string  num_keywords  \
# 0   film, series, season, episodes, characters, ma...            10
# 1   song, you, love, album, music, don, all, your,...            10
# 2   world, war, south, united, history, olympics, ...            10
# 3   states, united, new, state, act, york, america...            10
# 8   episodes, computer, video, game, software, sys...            10
# 9   law, theory, social, management, analysis, his...            10
# 10  football, league, basketball, baseball, season...            10
# 11  cup, surname, united, world, fifa, kingdom, fo...            10
# 13  office, season, paper, michael, day, night, an...            10
# 14  brady, days, our, lives, dimera, characters, h...            10
# 16  coronation, street, characters, barlow, connor...            10
# 17  gun, laws, new, carry, united, states, califor...            10
# 18  home, away, characters, stewart, braxton, king...            10
#
#                                              category  llm_correlation  \
# 0              film & tv content; actors & characters             0.80
# 1                          music & albums; love songs             0.60
# 2    global affairs; geography; sports & competitions             0.60
# 3   united states history; american states; nation...             0.95
# 8   computer games history; video game software; n...             0.60
# 9   legal & social studies; management & market an...             0.60
# 10  sports competitions; american team sports; sea...             0.90
# 11   football community; united kingdom; fifa matters             0.60
# 13               office workers; tv series characters             0.80
# 14  "days of our lives characters"; "horton-dimera...             0.60
# 16  coronation street characters; british soap ope...             0.90
# 17  gun laws in us states; concealed carry regulat...             0.80
# 18           characters at home; workplace characters             0.60
#
#     llm_match
# 0        True
# 1       False
# 2       False
# 3        True
# 8       False
# 9       False
# 10       True
# 11      False
# 13       True
# 14      False
# 16       True
# 17       True
# 18      False
