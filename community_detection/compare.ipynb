# %%
import json
import pandas as pd
from collections import Counter
import requests

# %%
communities = []
with open('output/run142-NQv0-best_run/run142_raw_communities.json', 'r') as f:
	communities = json.load(f)

communities_list = communities['louvain']
print(len(communities_list))
# Out:
# Loaded 4 communities

# %%
categories = pd.read_json('../data/categories.jsonl', lines=True)

# %%
with open('../data/v0.0/nodes.json', 'r', encoding='utf-8-sig') as f:
    data = json.load(f)

nodes = pd.json_normalize(data)

# %%
categories_merged = categories.merge(
    nodes[["d.identity", "d.properties.title_encode"]],
    left_on="title",
    right_on="d.properties.title_encode",
    how="left"
)

categories_merged = categories_merged.drop(columns=["d.properties.title_encode"])
categories_merged.head()
# Out:
#             example_id                                   title  \
# 0  4549465242785278785             The_Walking_Dead_(season_8)
# 1 -2543388002166163252                              Persephone
# 2  5985355041383167183                        Colony_(biology)
# 3 -2975172535563055798  The_Man_in_the_High_Castle_(TV_series)
# 4 -1052334833502528495       List_of_heads_of_state_of_Nigeria
#
#                                           categorias  \
# 0  [2017 American television seasons, The Walking...
# 1  [Greek goddesses, Queens in Greek mythology, L...
# 2  [Community ecology, Microbiology terms, Habita...
# 3  [2010s American drama television series, 2015 ...
# 4  [Government of Nigeria, Lists of political off...
#
#                                   categorias_ocultas  d.identity
# 0  [Official website different in Wikidata and Wi...         700
# 1  [Articles containing Mycenaean Greek-language ...        6930
# 2                                                 []        6931
# 3  [CS1 German-language sources (de), Use America...        4733
# 4                 [Official website not in Wikidata]        6932

# %%
community_map = {}
for i, ids in enumerate(communities_list):
    for node_id in ids:
        community_map[node_id] = i

categories_merged['community_id'] = categories_merged['d.identity'].map(community_map)

print(f"Comunidades atribuídas: {categories_merged['community_id'].nunique()}")
# Out:
# Comunidades atribuídas: 24

# %%
# --- Contar categorias e categorias_ocultas em cada comunidade ---
top20_per_community_wiki = {}

for i in range(len(communities_list)):
    subset = categories_merged[categories_merged['community_id'] == i]

    # 'categorias' e 'categorias_ocultas' são listas — precisamos achatar
    all_cats = [cat for cats in subset['categorias'].dropna() for cat in cats]
    all_hidden = [cat for cats in subset['categorias_ocultas'].dropna() for cat in cats]

    top_cats = Counter(all_cats).most_common(20)
    top_hidden = Counter(all_hidden).most_common(20)

    top20_per_community_wiki[i] = {
        "top_categorias": top_cats,
        "top_categorias_ocultas": top_hidden
    }

# %%
# Ler o arquivo JSON correto
with open('output/run142-NQv0-best_run/run142_community_keywords.json', 'r', encoding='utf-8') as f:
    data = json.load(f)

# Criar uma lista para o DataFrame
rows = []

# Iterar por todos os algoritmos e comunidades
for algorithm_name, communities in data.items():
    for comm_id, comm_data in communities.items():
        # Extrair keywords (apenas as palavras, sem as contagens)
        keywords = comm_data.get('keywords', [])
        keywords_list = [kw[0] for kw in keywords]
        keywords_string = ', '.join(keywords_list)
        
        rows.append({
            'algorithm': algorithm_name,
            'community_id': comm_id,
            'comm_name': comm_data.get('comm_name', ''),
            'keywords_string': keywords_string,
            'num_keywords': len(keywords_list)
        })

# Criar DataFrame
df = pd.DataFrame(rows)

print(df)
# Out:
#      algorithm community_id                            comm_name  \
# 0      infomap            0  Countries, History, European, World
# 1      infomap            1            States, United, New, York
# 2      infomap            2         Cell, System, Human, Disease
# 3      infomap            3    Computer, Software, Data, Windows
# 4      infomap            4    Church, Catholic, Bible, Biblical
# ...        ...          ...                                  ...
# 1327   k-means           35           Engine, Ford, Car, Vehicle
# 1328   k-means           36           Star, Film, Series, Comics
# 1329   k-means           37               Girl, Film, She, Woman
# 1330   k-means           38             States, United, Act, Law
# 1331   k-means           39    School, University, High, College
#
#                                         keywords_string  num_keywords
# 0     countries, history, european, world, economy, ...            10
# 1     states, united, new, york, state, national, ac...            10
# 2     cell, system, human, disease, muscle, history,...            10
# 3     computer, software, data, windows, system, pro...            10
# 4     church, catholic, bible, biblical, history, go...            10
# ...                                                 ...           ...
# 1327  engine, ford, car, vehicle, grand, prix, toyot...            10
# 1328  star, film, series, comics, wars, trek, season...            10
# 1329  girl, film, she, woman, queen, you, lady, litt...            10
# 1330  states, united, act, law, rights, federal, cou...            10
# 1331  school, university, high, college, institute, ...            10
#
# [1332 rows x 5 columns]

# %%
import requests
import pandas as pd

def categorize_with_ollama(keywords_string, model="gpt-oss:20b"):
    prompt = f"""
You are a precise classifier. Analyze the following keywords produced by a community detection algorithm and assign a short, meaningful category name (2–4 words maximum).

Keywords:
{keywords_string}

Return only the answer — no explanations, no text before or after.
"""

    data = {
        "model": model,
        "prompt": prompt,
        "stream": False,
        "options": {
            "seed": 42,
            "top_k": 1,
            "top_p": 1,
            "temperature": 0
        }
    }

    url = "http://localhost:11434/api/generate"
    headers = {"Content-Type": "application/json"}

    try:
        resp = requests.post(url, headers=headers, json=data, timeout=3000)
        resp.raise_for_status()
        result = resp.json()
        return result.get("response", "").strip().lower()
    except Exception as e:
        print(f"Erro ao categorizar: {e}")
        return "erro"

# %%
df.iloc[0]['keywords_string']
# Out:
# 'middle, earth, rings, lord, film, series, hobbit, ring, king, tolkien'

# %%
categorize_with_ollama('countries, history, european, world, economy, national, republic, flag, union, languages')

# %%
# Remove todos do algorithm=infomap
df = df[df['algorithm'] != 'infomap']
#exclui coluna descriptions
df = df.drop(columns=['description'])
df
# Out:
#      algorithm community_id                               comm_name  \
# 1249   louvain            0              Middle, Earth, Rings, Lord
# 1250   louvain            1                  Song, You, Love, Album
# 1251   louvain            2        India, Indian, Cricket, National
# 1252   louvain            3  Football, League, Basketball, Baseball
# 1253   louvain            4                Vegas, Las, Card, Casino
# ...        ...          ...                                     ...
# 1327   k-means           35              Engine, Ford, Car, Vehicle
# 1328   k-means           36              Star, Film, Series, Comics
# 1329   k-means           37                  Girl, Film, She, Woman
# 1330   k-means           38                States, United, Act, Law
# 1331   k-means           39       School, University, High, College
#
#                                         keywords_string  num_keywords  \
# 1249  middle, earth, rings, lord, film, series, hobb...            10
# 1250  song, you, love, album, music, don, all, your,...            10
# 1251  india, indian, cricket, national, pakistan, fi...            10
# 1252  football, league, basketball, baseball, season...            10
# 1253  vegas, las, card, casino, nascar, poker, game,...            10
# ...                                                 ...           ...
# 1327  engine, ford, car, vehicle, grand, prix, toyot...            10
# 1328  star, film, series, comics, wars, trek, season...            10
# 1329  girl, film, she, woman, queen, you, lady, litt...            10
# 1330  states, united, act, law, rights, federal, cou...            10
# 1331  school, university, high, college, institute, ...            10
#
#                         category
# 1249           lord of the rings
# 1250                  love songs
# 1251  south asian sports culture
# 1252              sports leagues
# 1253         vegas casino racing
# ...                          ...
# 1327    automotive racing brands
# 1328         entertainment media
# 1329      female film characters
# 1330     u.s. constitutional law
# 1331      education institutions
#
# [83 rows x 6 columns]

# %%
# category" = "erro"
df_correcao = df[df['category'] == 'erro']
df_correcao
# Out:
# Empty DataFrame
# Columns: [algorithm, community_id, comm_name, keywords_string, num_keywords, category]
# Index: []

# %%
import time
from concurrent.futures import ThreadPoolExecutor, as_completed

print("\nCategorizando comunidades com Ollama...")

def process_row(idx, row):
    """Função auxiliar que processa uma linha do DataFrame."""
    print(f"Processando {row['algorithm']} - comunidade {row['community_id']}...")
    category = categorize_with_ollama(row['keywords_string'])
    time.sleep(1)
    print(f"  -> Rows keywords: {row['keywords_string']}")
    print(f"  -> Categoria: {category}")
    return idx, category

results = []
with ThreadPoolExecutor(max_workers=32) as executor:
    futures = {executor.submit(process_row, idx, row): idx for idx, row in df_correcao.iterrows()}
    total = len(futures)
    processed = 0

    for future in as_completed(futures):
        idx, category = future.result()
        df_correcao.at[idx, 'category'] = category
        processed += 1
        if processed % 10 == 0 or processed == total:
            print(f"Processados {processed}/{total}")

print("\n=== DataFrame Final ===")
print(df_correcao.head(10))
# Out:
# Categorizando comunidades com Ollama...
# Processando leiden - comunidade 15...
# Processando k-means - comunidade 33...
#   -> Rows keywords: fire, art, color, black, glass, human, blue, red, ring, power
#   -> Categoria: colorful artifacts
#   -> Rows keywords: little, nyah, old, baby, mary, rain, down, man, row, round
#   -> Categoria: nursery rhyme
# Processados 2/2
#
# === DataFrame Final ===
#      algorithm community_id                comm_name  \
# 1288    leiden           15  Little, Nyah, Old, Baby
# 1325   k-means           33  Fire, Art, Color, Black
#
#                                         keywords_string  num_keywords  \
# 1288  little, nyah, old, baby, mary, rain, down, man...            10
# 1325  fire, art, color, black, glass, human, blue, r...            10
#
#                 category
# 1288       nursery rhyme
# 1325  colorful artifacts

# %%
#Atualiza df com as correções
for idx, row in df_correcao.iterrows():
	df.at[idx, 'category'] = row['category']
df.to_json('communities_categorized.json', orient='records', indent=2)

# %%
df.to_json('communities_categorized.json', orient='records', indent=2)
print("\nResultados salvos em communities_categorized.json ✅")
# Out:
# Resultados salvos em communities_categorized.json ✅

# %%
df = pd.read_json('communities_categorized.json', orient='records')
df = df[df['algorithm'] == 'louvain']
df
# Out:
#    algorithm  community_id                               comm_name  \
# 0    louvain             0              Middle, Earth, Rings, Lord
# 1    louvain             1                  Song, You, Love, Album
# 2    louvain             2        India, Indian, Cricket, National
# 3    louvain             3  Football, League, Basketball, Baseball
# 4    louvain             4                Vegas, Las, Card, Casino
# 5    louvain             5           Golf, Open, Championship, Pga
# 6    louvain             6             Cup, Surname, United, World
# 7    louvain             7               Top, America, Next, Model
# 8    louvain             8         History, Church, Roman, Ancient
# 9    louvain             9            Law, Management, Market, Tax
# 10   louvain            10          Film, Series, Season, Episodes
# 11   louvain            11              World, War, South, History
# 12   louvain            12                 Little, Old, Baby, Mary
# 13   louvain            13              Gun, Laws, New, California
# 14   louvain            14          Cell, History, Cuisine, System
# 15   louvain            15          Power, Energy, System, History
# 16   louvain            16                Titanic, Rms, Seas, Ship
# 17   louvain            17          Season, Vampire, Diaries, Home
# 18   louvain            18              States, United, New, State
# 19   louvain            19                Brady, Series, Days, Our
# 20   louvain            20             Dead, Walking, Season, Fear
# 21   louvain            21          Office, Season, Michael, Paper
# 22   louvain            22     Episodes, Computer, Video, Software
# 23   louvain            23  Coronation, Street, Characters, Barlow
#
#                                       keywords_string  num_keywords  \
# 0   middle, earth, rings, lord, film, series, hobb...            10
# 1   song, you, love, album, music, don, all, your,...            10
# 2   india, indian, cricket, national, pakistan, fi...            10
# 3   football, league, basketball, baseball, season...            10
# 4   vegas, las, card, casino, nascar, poker, game,...            10
# 5   golf, open, championship, pga, tour, cup, club...            10
# 6   cup, surname, united, world, football, kingdom...            10
# 7   top, america, next, model, cycle, wedding, sea...            10
# 8   history, church, roman, ancient, theory, socia...            10
# 9   law, management, market, tax, economics, busin...            10
# 10  film, series, season, episodes, characters, ma...            10
# 11  world, war, south, history, canada, olympics, ...            10
# 12  little, old, baby, mary, rain, down, song, man...            10
# 13  gun, laws, new, california, carry, united, sta...            10
# 14  cell, history, cuisine, system, human, medical...            10
# 15  power, energy, system, history, water, engine,...            10
# 16  titanic, rms, seas, ship, class, ships, film, ...            10
# 17  season, vampire, diaries, home, series, away, ...            10
# 18  states, united, new, state, act, york, america...            10
# 19  brady, series, days, our, lives, dimera, ninja...            10
# 20  dead, walking, season, fear, grimes, greene, p...            10
# 21  office, season, michael, paper, series, day, n...            10
# 22  episodes, computer, video, software, game, dat...            10
# 23  coronation, street, characters, barlow, connor...            10
#
#                            category
# 0                 lord of the rings
# 1                        love songs
# 2        south asian sports culture
# 3                    sports leagues
# 4               vegas casino racing
# 5                  golf tournaments
# 6   football clubs and competitions
# 7                 fashion & apparel
# 8             ancient roman culture
# 9                  business finance
# 10                        film & tv
# 11         global historical events
# 12                   nursery rhymes
# 13                   state gun laws
# 14         human health & nutrition
# 15        energy and transportation
# 16            titanic maritime film
# 17                television series
# 18            united states history
# 19               tv show characters
# 20                 the walking dead
# 21                       the office
# 22            video game technology
# 23                british tv dramas

# %%
top20_per_community_wiki
# Out:
# {0: {'top_categorias': [('The Lord of the Rings characters', 95),
#    ('English-language films', 85),
#    ('American films', 85),
#    ('New Zealand films', 84),
#    ('New Line Cinema films', 84),
#    ('American epic films', 80),
#    ('Fictional-language films', 80),
#    ('Film series', 80),
#    ('Films directed by Peter Jackson', 80),
#    ('The Lord of the Rings (film series)', 75),
#    ('High fantasy films', 69),
#    ('Film series introduced in 2001', 65),
#    ('2000s fantasy films', 65),
#    ('The Lord of the Rings', 65),
#    ('Allen &amp; Unwin books', 63),
#    ('Fictional characters introduced in 1954', 62),
#    ('British novels adapted into films', 61),
#    ('Sequel novels', 59),
#    ('1954 British novels', 56),
#    ('Adventure films by series', 54)],
#   'top_categorias_ocultas': [('Webarchive template wayback links', 138),
#    ('All articles with unsourced statements', 122),
#    ('Articles using Infobox character with multiple unlabeled fields', 114),
#    ('Good articles', 90),
#    ('Use dmy dates from January 2016', 87),
#    ('All articles that need to differentiate between fact and fiction', 87),
#    ('Pages using citations with accessdate and no URL', 79),
#    ('Wikipedia articles with VIAF identifiers', 67),
#    ('Wikipedia articles with LCCN identifiers', 66),
#    ('Use British English from January 2013', 65),
#    ('Interlanguage link template link number', 65),
#    ('Wikipedia articles with GND identifiers', 62),
#    ('All articles needing additional references', 57),
#    ('All articles lacking reliable references', 54),
#    ('Tolkien articles that need to differentiate between fact and fiction',
#     49),
#    ('Wikipedia articles with BNF identifiers', 48),
#    ('Use British English Oxford spelling from March 2014', 45),
#    ('All articles to be expanded', 42),
#    ('Articles using small message boxes', 42),
#    ('All pages needing factual verification', 41)]},
#  1: {'top_categorias': [('Billboard Hot 100 number-one singles', 3930),
#    ('UK Singles Chart number-one singles', 3507),
#    ('Number-one singles in Australia', 2687),
#    ('Irish Singles Chart number-one singles', 2389),
#    ('RPM Top Singles number-one singles', 2318),
#    ('Billboard Adult Contemporary number-one singles', 2290),
#    ('Pop ballads', 2124),
#    ('Columbia Records singles', 2004),
#    ('Number-one singles in New Zealand', 1960),
#    ('Debut singles', 1646),
#    ('Number-one singles in Norway', 1607),
#    ('Billboard Hot R&amp;B/Hip-Hop Songs number-one singles', 1502),
#    ('Billboard Hot Country Songs number-one singles', 1468),
#    ('Rock ballads', 1456),
#    ('Dutch Top 40 number-one singles', 1378),
#    ('Number-one singles in Germany', 1366),
#    ('European Hot 100 Singles number-one singles', 1311),
#    ('Number-one singles in Sweden', 1304),
#    ('Number-one singles in Switzerland', 1280),
#    ('Living people', 1238)],
#   'top_categorias_ocultas': [('Articles with hAudio microformats', 22687),
#    ('Singlechart called without song', 9533),
#    ('All articles with unsourced statements', 8846),
#    ('Singlechart usages for Billboardhot100', 7188),
#    ('Singlechart called without artist', 6769),
#    ('Music infoboxes with deprecated parameters', 6407),
#    ('Singlechart usages for New Zealand', 6077),
#    ('All articles needing additional references', 6065),
#    ('Certification Table Entry usages for United States', 5829),
#    ('Singlechart usages for Austria', 5625),
#    ('Singlechart usages for Dutch100', 5536),
#    ('Certification Table Entry usages for United Kingdom', 5429),
#    ('Singlechart usages for Flanders', 5376),
#    ('Singlechart usages for Australia', 5118),
#    ('Webarchive template wayback links', 4973),
#    ('Singlechart usages for Sweden', 4893),
#    ('Singlechart usages for UK', 4849),
#    ('Singlechart usages for France', 4617),
#    ('Singlechart usages for Dutch40', 4492),
#    ('CS1 German-language sources (de)', 4488)]},
#  2: {'top_categorias': [('Indian films', 802),
#    ('Living people', 403),
#    ('Hindi-language films', 341),
#    ('Constitution of India', 341),
#    ('Hindi-language television programs', 319),
#    ('Parliament of India', 293),
#    ('Independent India', 280),
#    ('2010s Indian television series', 276),
#    ('History of West Bengal', 256),
#    ('Indian drama television series', 254),
#    ('Indian independence movement', 254),
#    ('2010s Hindi-language films', 243),
#    ('History of Bengal', 226),
#    ('Indian reality television series', 226),
#    ('History of Kolkata', 220),
#    ('Star Plus television series', 219),
#    ('History of Pakistan', 213),
#    ('Political history of India', 206),
#    ('2000s Hindi-language films', 191),
#    ('Lists of political office-holders in India', 188)],
#   'top_categorias_ocultas': [('All Wikipedia articles written in Indian English',
#     7050),
#    ('All articles with unsourced statements', 3891),
#    ('Webarchive template wayback links', 2749),
#    ('All articles needing additional references', 2647),
#    ('All articles with dead external links', 1641),
#    ('Coordinates on Wikidata', 1550),
#    ('Articles with permanently dead external links', 1103),
#    ('Wikipedia articles with GND identifiers', 1103),
#    ('Articles with hAudio microformats', 1085),
#    ('Wikipedia articles with VIAF identifiers', 1071),
#    ('All articles containing potentially dated statements', 953),
#    ('Use Indian English from June 2016', 808),
#    ('Wikipedia articles with LCCN identifiers', 782),
#    ('Use dmy dates from March 2013', 713),
#    ('Articles with hCards', 709),
#    ('All articles lacking reliable references', 678),
#    ('Wikipedia articles with BNF identifiers', 663),
#    ('Wikipedia indefinitely semi-protected pages', 657),
#    ('CS1 maint: Multiple names: authors list', 636),
#    ('Wikipedia articles with ISNI identifiers', 624)]},
#  3: {'top_categorias': [('Living people', 1209),
#    ('National Basketball Association lists', 894),
#    ('National Football League teams', 882),
#    ('Lists of sports championships', 433),
#    ('Major League Baseball teams', 408),
#    ('Major League Baseball lists', 407),
#    ('National Basketball Association statistical leaders', 390),
#    ('Super Bowl', 388),
#    ('African-American basketball players', 382),
#    ('Annual sporting events in the United States', 373),
#    ('National Basketball Association All-Stars', 315),
#    ('World Series', 300),
#    ('United States men&#39;s national basketball team players', 286),
#    ('Parade High School All-Americans (boys&#39; basketball)', 278),
#    ('Super Bowl lists', 278),
#    ('National Basketball Association teams', 266),
#    ('Sports clubs established in 1960', 266),
#    ('McDonald&#39;s High School All-Americans', 265),
#    ('American football quarterbacks', 259),
#    ('Olympic gold medalists for the United States in basketball', 257)],
#   'top_categorias_ocultas': [('All articles with unsourced statements', 4036),
#    ('Webarchive template wayback links', 3158),
#    ('Articles with hCards', 3021),
#    ('All articles with dead external links', 2459),
#    ('All articles needing additional references', 2369),
#    ('Articles with permanently dead external links', 1555),
#    ('Featured lists', 1209),
#    ('Wikipedia articles with VIAF identifiers', 1114),
#    ('Wikipedia articles with LCCN identifiers', 1044),
#    ('Pages using deprecated image syntax', 889),
#    ('All articles containing potentially dated statements', 810),
#    ('Wikipedia indefinitely semi-protected pages', 740),
#    ('Wikipedia pages semi-protected against vandalism', 720),
#    ('Coordinates on Wikidata', 678),
#    ('Good articles', 646),
#    ('Pages containing links to subscription-only content', 578),
#    ('Official website different in Wikidata and Wikipedia', 549),
#    ('Pages with citations lacking titles', 548),
#    ('Pages using citations with accessdate and no URL', 547),
#    ('CS1 maint: Multiple names: authors list', 509)]},
#  4: {'top_categorias': [('Fast-food chains of the United States', 272),
#    ('Fast-food franchises', 198),
#    ('Las Vegas Strip', 169),
#    ('Restaurant chains in the United States', 130),
#    ('Skyscraper hotels in Paradise, Nevada', 102),
#    ('Casino hotels', 100),
#    ('Casinos in the Las Vegas Valley', 94),
#    ('Resorts in the Las Vegas Valley', 93),
#    ('Fast-food hamburger restaurants', 91),
#    ('Regional restaurant chains in the United States', 81),
#    ('McDonald&#39;s', 71),
#    ('NASCAR drivers', 69),
#    ('21st-century American racing drivers', 63),
#    ('Fast-food poultry restaurants', 62),
#    ('20th-century American racing drivers', 62),
#    ('Living people', 61),
#    ('Landmarks in Nevada', 59),
#    ('Economy of the Southeastern United States', 58),
#    ('Companies listed on NASDAQ', 54),
#    ('Mandalay Bay', 52)],
#   'top_categorias_ocultas': [('All articles with unsourced statements', 669),
#    ('All articles with dead external links', 384),
#    ('Webarchive template wayback links', 345),
#    ('Pages using deprecated image syntax', 338),
#    ('All articles needing additional references', 301),
#    ('Coordinates on Wikidata', 242),
#    ('Articles with permanently dead external links', 219),
#    ('All articles containing potentially dated statements', 196),
#    ('Pages containing links to subscription-only content', 173),
#    ('Official website different in Wikidata and Wikipedia', 173),
#    ('All articles lacking reliable references', 131),
#    ('Wikipedia articles with VIAF identifiers', 118),
#    ('Wikipedia articles with LCCN identifiers', 106),
#    ('Pages with citations lacking titles', 93),
#    ('Pages with citations having bare URLs', 91),
#    ('Pages using citations with accessdate and no URL', 89),
#    ('Wikipedia indefinitely semi-protected pages', 79),
#    ('All Wikipedia articles written in American English', 71),
#    ('All articles with vague or ambiguous time', 68),
#    ('Articles with hCards', 66)]},
#  5: {'top_categorias': [('Men&#39;s major golf championships', 121),
#    ('Golf terminology', 78),
#    ('Masters Tournament', 76),
#    ('Annual sporting events in the United States', 70),
#    ('Lists of male golfers', 66),
#    ('Winners of men&#39;s major golf championships', 63),
#    ('PGA Tour events', 61),
#    ('U.S. Open (golf)', 57),
#    ('2018 in golf', 53),
#    ('The Open Championship', 49),
#    ('Recurring sporting events established in 1934', 44),
#    ('Economy of Augusta, Georgia', 44),
#    ('Tourist attractions in Augusta, Georgia', 44),
#    ('1934 establishments in Georgia (U.S. state)', 44),
#    ('Golf tournaments in the United States', 44),
#    ('April sporting events', 44),
#    ('Golf records and rankings', 44),
#    ('PGA Tour golfers', 42),
#    ('2017 in golf', 40),
#    ('Golf tournaments in England', 34)],
#   'top_categorias_ocultas': [('Coordinates not on Wikidata', 167),
#    ('All articles with unsourced statements', 129),
#    ('Articles with hCards', 111),
#    ('All articles needing additional references', 85),
#    ('Coordinates on Wikidata', 82),
#    ('Webarchive template wayback links', 76),
#    ('Official website different in Wikidata and Wikipedia', 73),
#    ('Good articles', 50),
#    ('Official website not in Wikidata', 50),
#    ('Use mdy dates from April 2017', 44),
#    ('Articles with unsourced statements from February 2013', 44),
#    ('Articles with unsourced statements from April 2018', 44),
#    ('Featured lists', 44),
#    ('All articles with dead external links', 42),
#    ('Pages using deprecated image syntax', 31),
#    ('Pages using div col with small parameter', 31),
#    ('Articles with short description', 29),
#    ('Wikipedia articles with GND identifiers', 25),
#    ('Wikipedia articles with LCCN identifiers', 25),
#    ('Articles needing additional references from October 2011', 25)]},
#  6: {'top_categorias': [('Surnames', 566),
#    ('Countries at the FIFA World Cup', 522),
#    ('2018 FIFA World Cup', 515),
#    ('Living people', 458),
#    ('FIFA World Cup tournaments', 458),
#    ('FIFA World Cup-related lists', 388),
#    ('Association football records and statistics', 351),
#    ('FIFA World Cup statistics', 255),
#    ('Association football forwards', 245),
#    ('British monarchy', 239),
#    ('Premier League players', 236),
#    ('La Liga players', 224),
#    ('History of the England national football team', 216),
#    ('2018 in association football', 213),
#    ('International association football competitions hosted by Russia', 212),
#    ('UEFA Champions League winning players', 207),
#    ('July 2018 sports events in Europe', 206),
#    ('June 2018 sports events in Europe', 205),
#    ('England at the FIFA World Cup', 204),
#    ('Football clubs in England', 204)],
#   'top_categorias_ocultas': [('All articles with unsourced statements', 3669),
#    ('Webarchive template wayback links', 3054),
#    ('All articles needing additional references', 2011),
#    ('All articles with dead external links', 1870),
#    ('Wikipedia articles with GND identifiers', 1573),
#    ('Wikipedia articles with VIAF identifiers', 1384),
#    ('Articles with permanently dead external links', 1326),
#    ('Wikipedia articles with LCCN identifiers', 1164),
#    ('Coordinates on Wikidata', 1100),
#    ('Articles with hCards', 1029),
#    ('Pages using deprecated image syntax', 1023),
#    ('CS1 Spanish-language sources (es)', 969),
#    ('Wikipedia articles with BNF identifiers', 737),
#    ('Wikipedia articles with ISNI identifiers', 715),
#    ('All articles containing potentially dated statements', 701),
#    ('Featured articles', 687),
#    ('Pages containing links to subscription-only content', 618),
#    ('CS1: Julianâ\x80\x93Gregorian uncertainty', 617),
#    ('All set index articles', 595),
#    ('CS1 Italian-language sources (it)', 588)]},
#  7: {'top_categorias': [('America&#39;s Next Top Model', 114),
#    ('History of clothing (Western fashion)', 47),
#    ('20th-century fashion', 36),
#    ('History of fashion', 35),
#    ('2018 American television seasons', 35),
#    ('19th-century fashion', 34),
#    ('Marriage', 32),
#    ('Wedding', 30),
#    ('21st-century fashion', 28),
#    ('ETC (TV channel) shows', 25),
#    ('Pre-wedding', 21),
#    ('Trousers and shorts', 19),
#    ('2000s fashion', 17),
#    ('Formal wear', 16),
#    ('2010s fashion', 15),
#    ('Hats', 15),
#    ('Wedding traditions', 15),
#    ('Dresses', 14),
#    ('Licenses', 14),
#    ('Vital statistics', 14)],
#   'top_categorias_ocultas': [('All articles with unsourced statements', 173),
#    ('All articles needing additional references', 170),
#    ('Use mdy dates from August 2017', 79),
#    ('Webarchive template wayback links', 73),
#    ('All articles with dead external links', 57),
#    ('Articles needing additional references from August 2009', 36),
#    ('All articles lacking reliable references', 36),
#    ('Articles needing additional references from January 2018', 35),
#    ('Use mdy dates from December 2017', 35),
#    ('Official website not in Wikidata', 34),
#    ('Wikipedia articles with GND identifiers', 32),
#    ('Articles with unsourced statements from May 2014', 25),
#    ('Articles with permanently dead external links', 25),
#    ('CS1 maint: BOT: original-url status unknown', 24),
#    ('CS1 maint: Unfit url', 22),
#    ('Articles lacking reliable references from May 2016', 21),
#    ('Commons category with local link different than on Wikidata', 19),
#    ('Articles needing additional references from November 2011', 18),
#    ('Articles with unsourced statements from August 2017', 17),
#    ('Articles needing additional references from May 2016', 17)]},
#  8: {'top_categorias': [('Christian terminology', 1104),
#    ('Biblical phrases', 383),
#    ('Former empires', 267),
#    ('Former countries in Europe', 236),
#    ('Former countries in Asia', 208),
#    ('Public holidays in the United States', 184),
#    ('New Testament books', 179),
#    ('Former countries in Africa', 174),
#    ('Chinese architectural history', 171),
#    ('Great Wall of China', 167),
#    ('English-language idioms', 167),
#    ('Islamic terminology', 153),
#    ('American films', 151),
#    ('French Revolution', 143),
#    ('English-language films', 143),
#    ('Hebrew Bible words and phrases', 142),
#    ('Cultural lists', 140),
#    ('Book of Genesis', 136),
#    ('Historical eras', 132),
#    ('Canonical epistles', 130)],
#   'top_categorias_ocultas': [('All articles with unsourced statements', 9550),
#    ('Wikipedia articles with GND identifiers', 5944),
#    ('Webarchive template wayback links', 5097),
#    ('All articles needing additional references', 4134),
#    ('Wikipedia articles with VIAF identifiers', 3261),
#    ('Wikipedia articles with LCCN identifiers', 2878),
#    ('Wikipedia articles with BNF identifiers', 2709),
#    ('Articles containing Ancient Greek-language text', 2458),
#    ('All articles with dead external links', 2365),
#    ('Articles containing Latin-language text', 1881),
#    ('Coordinates on Wikidata', 1750),
#    ('Articles with permanently dead external links', 1391),
#    ('Articles containing Hebrew-language text', 1339),
#    ('All articles with specifically marked weasel-worded phrases', 1336),
#    ('CS1 maint: Extra text: authors list', 1275),
#    ('All articles lacking reliable references', 1273),
#    ('Articles containing French-language text', 1234),
#    ('CS1 maint: Multiple names: authors list', 1201),
#    ('Interlanguage link template link number', 1131),
#    ('CS1 French-language sources (fr)', 1126)]},
#  9: {'top_categorias': [('Business terms', 162),
#    ('Contract law', 120),
#    ('Accounting terminology', 102),
#    ('Production economics', 101),
#    ('Legal doctrines and principles', 92),
#    ('Business law', 85),
#    ('Economic systems', 81),
#    ('Common law', 75),
#    ('Criminal law', 72),
#    ('Capitalism', 71),
#    ('Management', 66),
#    ('Labour relations', 66),
#    ('Financial markets', 66),
#    ('Real property law', 65),
#    ('Types of business entity', 65),
#    ('Legal terminology', 63),
#    ('Latin legal terminology', 62),
#    ('Corporate law', 62),
#    ('Payment systems', 61),
#    ('Working time', 61)],
#   'top_categorias_ocultas': [('All articles with unsourced statements', 1888),
#    ('All articles needing additional references', 1104),
#    ('Webarchive template wayback links', 837),
#    ('Wikipedia articles with GND identifiers', 775),
#    ('All articles with dead external links', 437),
#    ('All articles with specifically marked weasel-worded phrases', 315),
#    ('Articles with permanently dead external links', 290),
#    ('Wikipedia articles with NDL identifiers', 248),
#    ('Wikipedia articles with LCCN identifiers', 246),
#    ('Articles with multiple maintenance issues', 235),
#    ('All stub articles', 206),
#    ('CS1 maint: Multiple names: authors list', 206),
#    ('All articles containing potentially dated statements', 185),
#    ('Articles using small message boxes', 177),
#    ('All articles to be expanded', 174),
#    ('All articles that may contain original research', 169),
#    ('All pages needing cleanup', 166),
#    ('All articles lacking in-text citations', 146),
#    ('All Wikipedia articles in need of updating', 135),
#    ('Pages using citations with accessdate and no URL', 130)]},
#  10: {'top_categorias': [('English-language films', 16122),
#    ('American films', 14372),
#    ('English-language television programs', 8890),
#    ('Living people', 7523),
#    ('IMAX films', 3109),
#    ('American male film actors', 2860),
#    ('American male television actors', 2816),
#    ('American sequel films', 2624),
#    ('American television actresses', 2593),
#    ('American film actresses', 2484),
#    ('2010s American drama television series', 2332),
#    ('2017 films', 2205),
#    ('21st-century American actresses', 2178),
#    ('Films featuring anthropomorphic characters', 2142),
#    ('21st-century American male actors', 2083),
#    ('20th-century American male actors', 2080),
#    ('British films', 1901),
#    ('2010s American television series', 1896),
#    ('Universal Pictures films', 1894),
#    ('20th-century American actresses', 1885)],
#   'top_categorias_ocultas': [('All articles with unsourced statements', 16098),
#    ('Wikipedia articles with VIAF identifiers', 13051),
#    ('Wikipedia articles with LCCN identifiers', 10747),
#    ('Wikipedia articles with GND identifiers', 10039),
#    ('All articles needing additional references', 9271),
#    ('Articles with hCards', 9238),
#    ('Webarchive template wayback links', 9116),
#    ('Wikipedia articles with BNF identifiers', 8167),
#    ('All articles with dead external links', 6624),
#    ('Wikipedia articles with ISNI identifiers', 5899),
#    ('Articles with hAudio microformats', 5313),
#    ('Good articles', 5080),
#    ('All articles containing potentially dated statements', 4310),
#    ('Pages using deprecated image syntax', 4283),
#    ('Official website different in Wikidata and Wikipedia', 4013),
#    ('Articles with permanently dead external links', 3682),
#    ('Pages using citations with accessdate and no URL', 3432),
#    ('Music infoboxes with deprecated parameters', 3117),
#    ('Album infoboxes lacking a cover', 2688),
#    ('Pages using infobox television with editor parameter', 2672)]},
#  11: {'top_categorias': [('Member states of the United Nations', 695),
#    ('Visa requirements by nationality', 512),
#    ('Living people', 456),
#    ('Lists of countries', 400),
#    ('English-speaking countries and territories', 337),
#    ('Minimum ages', 315),
#    ('Republics', 293),
#    ('National flags', 256),
#    ('Member states of the Commonwealth of Nations', 243),
#    ('Lists by country', 242),
#    ('Law-related lists', 241),
#    ('Traffic law', 238),
#    ('World War I', 237),
#    ('Wars involving the United Kingdom', 234),
#    ('Visa policy by country', 216),
#    ('2010s South Korean television series', 211),
#    ('Wars involving France', 207),
#    ('Wars involving the United States', 201),
#    ('Former Spanish colonies', 199),
#    ('Extreme points of Earth', 195)],
#   'top_categorias_ocultas': [('All articles with unsourced statements', 15039),
#    ('Webarchive template wayback links', 11595),
#    ('All articles needing additional references', 7946),
#    ('All articles with dead external links', 6687),
#    ('Wikipedia articles with GND identifiers', 6682),
#    ('Coordinates on Wikidata', 5065),
#    ('Wikipedia articles with VIAF identifiers', 4670),
#    ('Articles with permanently dead external links', 4357),
#    ('All articles containing potentially dated statements', 3731),
#    ('Wikipedia articles with LCCN identifiers', 3658),
#    ('Wikipedia articles with BNF identifiers', 2995),
#    ('CS1 Spanish-language sources (es)', 2629),
#    ('CS1 French-language sources (fr)', 2572),
#    ('Articles with hAudio microformats', 2196),
#    ('CS1 German-language sources (de)', 2154),
#    ('Wikipedia indefinitely move-protected pages', 2063),
#    ('Articles containing French-language text', 2028),
#    ('CS1 maint: Multiple names: authors list', 1867),
#    ('All articles lacking reliable references', 1804),
#    ('Pages using deprecated image syntax', 1697)]},
#  12: {'top_categorias': [('Roud Folk Song Index songs', 277),
#    ('English nursery rhymes', 260),
#    ('Children&#39;s songs', 164),
#    ('Year of song unknown', 138),
#    ('Songwriter unknown', 120),
#    ('Singing games', 99),
#    ('Lullabies', 46),
#    ('American nursery rhymes', 44),
#    ('English folk songs', 43),
#    ('1790s in England', 42),
#    ('1881 songs', 42),
#    ('1881 in England', 42),
#    ('Urban legends', 42),
#    ('English folklore', 33),
#    ('Songs about London', 33),
#    ('Riddles', 30),
#    ('Nursery rhymes', 29),
#    ('Songs about children', 29),
#    ('Music education', 27),
#    ('Songs about women', 27)],
#   'top_categorias_ocultas': [('Articles with hAudio microformats', 165),
#    ('Good articles', 106),
#    ('All articles with unsourced statements', 90),
#    ('All articles needing additional references', 62),
#    ('CS1 maint: Extra text: authors list', 49),
#    ('CS1: Julianâ\x80\x93Gregorian uncertainty', 39),
#    ('All articles lacking reliable references', 37),
#    ('Webarchive template wayback links', 29),
#    ('All articles with dead external links', 24),
#    ('Articles with dead external links from July 2017', 22),
#    ('Use dmy dates from January 2015', 22),
#    ('Articles containing potentially dated statements from April 2008', 22),
#    ('All articles containing potentially dated statements', 22),
#    ('Articles lacking reliable references from May 2015', 22),
#    ('Use dmy dates from July 2012', 18),
#    ('Commons category with page title different than on Wikidata', 18),
#    ('Articles with trivia sections from March 2017', 14),
#    ('All articles with trivia sections', 14),
#    ('Articles with unsourced statements from December 2017', 12),
#    ('Articles with unsourced statements from July 2012', 12)]},
#  13: {'top_categorias': [('United States gun laws by state', 332),
#    ('Texas law', 48),
#    ('Michigan law', 21),
#    ('Indiana law', 18),
#    ('New York (state) law', 16),
#    ('Virginia law', 14),
#    ('Florida law', 13),
#    ('California law', 12),
#    ('North Carolina law', 12),
#    ('United States firearms law', 11),
#    ('Gun politics in the United States', 11),
#    ('Missouri law', 10),
#    ('Licenses', 10),
#    ('Self-defense', 10),
#    ('Washington (state) law', 10),
#    ('Colorado law', 10),
#    ('Tennessee law', 10),
#    ('Pennsylvania law', 9),
#    ('Alabama law', 9),
#    ('New Jersey law', 8)],
#   'top_categorias_ocultas': [('All articles with unsourced statements', 85),
#    ('Webarchive template wayback links', 78),
#    ('Pages with citations lacking titles', 58),
#    ('Pages with citations having bare URLs', 58),
#    ('All articles containing potentially dated statements', 35),
#    ('All articles lacking reliable references', 31),
#    ('Articles with unsourced statements from December 2010', 26),
#    ('Articles with unsourced statements from August 2017', 22),
#    ('Use mdy dates from February 2014', 21),
#    ('Articles lacking reliable references from December 2015', 21),
#    ('All articles needing additional references', 20),
#    ('All articles with dead external links', 18),
#    ('Articles with unsourced statements from June 2016', 18),
#    ('Articles needing POV-check from November 2014', 16),
#    ('Articles with unsourced statements from July 2017', 16),
#    ('Articles with unsourced statements from September 2014', 16),
#    ('Use mdy dates from March 2015', 13),
#    ('CS1 maint: BOT: original-url status unknown', 12),
#    ('All articles with failed verification', 12),
#    ('Articles with failed verification from June 2016', 12)]},
#  14: {'top_categorias': [('Wikipedia articles incorporating text from the 20th edition of Gray&#39;s Anatomy (1918)',
#     453),
#    ('IUCN Red List least concern species', 412),
#    ('Metabolism', 392),
#    ('Cellular respiration', 366),
#    ('Digestive system', 340),
#    ('Plant physiology', 296),
#    ('Cell biology', 279),
#    ('Molecular biology', 250),
#    ('Membrane biology', 236),
#    ('Photosynthesis', 227),
#    ('Skeletal system', 223),
#    ('Organs (anatomy)', 204),
#    ('Taxa named by Carl Linnaeus', 200),
#    ('Nutrition', 196),
#    ('Cell anatomy', 193),
#    ('Genetics', 189),
#    ('Organelles', 185),
#    ('Cardiac anatomy', 181),
#    ('Human female endocrine system', 180),
#    ('Mammals described in 1758', 174)],
#   'top_categorias_ocultas': [('All articles with unsourced statements', 8998),
#    ('Webarchive template wayback links', 4019),
#    ('All articles needing additional references', 3925),
#    ('Wikipedia articles with GND identifiers', 3599),
#    ('CS1 maint: Multiple names: authors list', 3011),
#    ('Articles with &#39;species&#39; microformats', 2417),
#    ('All articles with dead external links', 2071),
#    ('Pages with unresolved properties', 1645),
#    ('CS1 maint: Uses authors parameter', 1473),
#    ('Articles with permanently dead external links', 1348),
#    ('Wikipedia articles with LCCN identifiers', 1259),
#    ('Wikipedia articles with NDL identifiers', 1176),
#    ('Wikipedia indefinitely move-protected pages', 1149),
#    ('Articles containing video clips', 1104),
#    ('All articles lacking reliable references', 1073),
#    ('CS1 maint: Extra text: authors list', 1066),
#    ('Wikipedia indefinitely semi-protected pages', 1015),
#    ('Good articles', 998),
#    ('All articles to be expanded', 852),
#    ('Articles using small message boxes', 830)]},
#  15: {'top_categorias': [('All-wheel-drive vehicles', 478),
#    ('2000s automobiles', 458),
#    ('2010s automobiles', 453),
#    ('Rear-wheel-drive vehicles', 362),
#    ('Front-wheel-drive vehicles', 329),
#    ('Motor vehicles manufactured in the United States', 303),
#    ('1990s automobiles', 269),
#    ('Concepts in physics', 263),
#    ('Plate tectonics', 231),
#    ('Chemical elements', 229),
#    ('Physical quantities', 225),
#    ('American inventions', 212),
#    ('CoupÃ©s', 211),
#    ('Periodic table', 189),
#    ('Structure of the Earth', 186),
#    ('Sedans', 185),
#    ('Earth', 183),
#    ('Oceanographical terminology', 172),
#    ('Units of time', 170),
#    ('Hatchbacks', 165)],
#   'top_categorias_ocultas': [('All articles with unsourced statements', 7953),
#    ('Webarchive template wayback links', 4948),
#    ('Wikipedia articles with GND identifiers', 4485),
#    ('All articles needing additional references', 4065),
#    ('All articles with dead external links', 2561),
#    ('CS1 maint: Multiple names: authors list', 1859),
#    ('Articles with permanently dead external links', 1720),
#    ('Wikipedia articles with LCCN identifiers', 1661),
#    ('Articles containing video clips', 1527),
#    ('All articles containing potentially dated statements', 1258),
#    ('Wikipedia articles with BNF identifiers', 1041),
#    ('Wikipedia indefinitely semi-protected pages', 1025),
#    ('CS1 German-language sources (de)', 993),
#    ('Wikipedia indefinitely move-protected pages', 910),
#    ('Wikipedia articles with NDL identifiers', 874),
#    ('Good articles', 863),
#    ('All articles lacking reliable references', 705),
#    ('CS1 maint: Uses authors parameter', 704),
#    ('CS1 French-language sources (fr)', 700),
#    ('CS1: Julianâ\x80\x93Gregorian uncertainty', 692)]},
#  16: {'top_categorias': [('RMS Titanic', 136),
#    ('1912 in Canada', 99),
#    ('1912 in the United Kingdom', 99),
#    ('1912 in the United States', 99),
#    ('Maritime incidents in 1912', 83),
#    ('Ship collisions with icebergs', 81),
#    ('1910s in Newfoundland', 80),
#    ('1911 ships', 78),
#    ('History of Halifax, Nova Scotia', 78),
#    ('Ships sunk in collisions', 78),
#    ('Shipwrecks of the Newfoundland and Labrador coast', 78),
#    ('Passenger ships of the United Kingdom', 70),
#    ('Deaths due to shipwreck', 67),
#    ('Four funnel liners', 66),
#    ('Steamships of the United Kingdom', 66),
#    ('Olympic-class ocean liners', 65),
#    ('Ships of the White Star Line', 65),
#    ('Deaths by drowning', 64),
#    ('Ships built by Harland and Wolff', 63),
#    ('Ships built in Belfast', 63)],
#   'top_categorias_ocultas': [('All articles with unsourced statements', 137),
#    ('All articles needing additional references', 108),
#    ('Wikipedia articles with VIAF identifiers', 101),
#    ('Wikipedia articles with LCCN identifiers', 100),
#    ('Coordinates on Wikidata', 94),
#    ('Articles with hAudio microformats', 82),
#    ('Webarchive template wayback links', 80),
#    ('Wikipedia articles with GND identifiers', 74),
#    ('Pages using deprecated image syntax', 73),
#    ('Pages using citations with accessdate and no URL', 72),
#    ('Wikipedia articles with SNAC-ID identifiers', 71),
#    ('Use British English from July 2014', 66),
#    ('Wikipedia indefinitely semi-protected pages', 64),
#    ('CS1: Julianâ\x80\x93Gregorian uncertainty', 61),
#    ('CS1 maint: BOT: original-url status unknown', 60),
#    ('Articles with unsourced statements from February 2013', 59),
#    ('Wikipedia articles needing page number citations from March 2012', 59),
#    ('Wikipedia indefinitely move-protected pages', 59),
#    ('Use dmy dates from April 2017', 59),
#    ('Articles needing additional references from April 2017', 59)]},
#  17: {'top_categorias': [('2010s Australian television series', 248),
#    ('English-language television programs', 248),
#    ('The Vampire Diaries characters', 135),
#    ('Fictional vampires', 125),
#    ('2015 Australian television series debuts', 118),
#    ('Australian reality television series', 117),
#    ('The Vampire Diaries', 91),
#    ('Seven Network shows', 85),
#    ('Network Ten shows', 82),
#    ('The Originals', 78),
#    ('2014 American television episodes', 76),
#    ('Fictional characters introduced in 1991', 72),
#    ('Characters in American novels of the 20th century', 65),
#    ('Australian drama television series', 64),
#    ('Home and Away characters', 63),
#    ('The Vampire Diaries (season 2) episodes', 62),
#    ('2013 Australian television series debuts', 60),
#    ('Television series by ITV Studios', 55),
#    ('The Vampire Diaries (season 5) episodes', 55),
#    ('The Bachelor seasons', 55)],
#   'top_categorias_ocultas': [('All Wikipedia articles written in Australian English',
#     301),
#    ('Official website not in Wikidata', 135),
#    ('All Wikipedia articles with plot summary needing attention', 128),
#    ('Wikipedia articles with plot summary needing attention from November 2016',
#     107),
#    ('Use mdy dates from October 2016', 102),
#    ('Pages using deprecated image syntax', 92),
#    ('Articles using Infobox character with multiple unlabeled fields', 82),
#    ('All articles with unsourced statements', 82),
#    ('Official website different in Wikidata and Wikipedia', 77),
#    ('All articles with dead external links', 65),
#    ('Use Australian English from February 2015', 51),
#    ('Use dmy dates from February 2015', 51),
#    ('All articles needing additional references', 51),
#    ('Webarchive template wayback links', 47),
#    ('Articles with hCards', 47),
#    ('Use dmy dates from January 2016', 45),
#    ('Use Australian English from January 2016', 45),
#    ('Pages containing links to subscription-only content', 44),
#    ('Use Australian English from September 2013', 42),
#    ('Pages using citations with accessdate and no URL', 38)]},
#  18: {'top_categorias': [('Legal history of the United States', 625),
#    ('History of United States expansionism', 581),
#    ('Wars involving the United States', 572),
#    ('Amendments to the United States Constitution', 562),
#    ('National symbols of the United States', 496),
#    ('States of the United States', 491),
#    ('History of the United States (1865â\x80\x931918)', 483),
#    ('1789 establishments in the United States', 454),
#    ('History of the United States (1776â\x80\x9389)', 441),
#    ('United States Supreme Court cases', 438),
#    ('American Revolution', 433),
#    ('History of the United States (1789â\x80\x931849)', 394),
#    ('Historic Civil Engineering Landmarks', 375),
#    ('United States historical documents', 371),
#    ('Economic history of the United States', 353),
#    ('Legislative branch of the United States government', 352),
#    ('Official documents of the United States', 334),
#    ('Living people', 323),
#    ('Progressive Era in the United States', 322),
#    ('United States Declaration of Independence', 321)],
#   'top_categorias_ocultas': [('All articles with unsourced statements', 15907),
#    ('Webarchive template wayback links', 13218),
#    ('Coordinates on Wikidata', 8047),
#    ('All articles needing additional references', 7720),
#    ('All articles with dead external links', 7645),
#    ('Wikipedia articles with GND identifiers', 6747),
#    ('Wikipedia articles with VIAF identifiers', 5703),
#    ('Wikipedia articles with LCCN identifiers', 5198),
#    ('All articles containing potentially dated statements', 4632),
#    ('Articles with permanently dead external links', 4396),
#    ('CS1: Julianâ\x80\x93Gregorian uncertainty', 3490),
#    ('CS1 maint: Multiple names: authors list', 3004),
#    ('Pages using deprecated image syntax', 2667),
#    ('Wikipedia articles with BNF identifiers', 2614),
#    ('Wikipedia indefinitely move-protected pages', 2573),
#    ('Wikipedia indefinitely semi-protected pages', 2485),
#    ('Wikipedia articles with ISNI identifiers', 2247),
#    ('Articles with hAudio microformats', 2218),
#    ('All Wikipedia articles written in American English', 2203),
#    ('CS1 maint: Extra text: authors list', 2042)]},
#  19: {'top_categorias': [('Days of Our Lives characters', 203),
#    ('NBC network shows', 167),
#    ('English-language television programs', 139),
#    ('2010s American television series', 96),
#    ('Television series by Universal Television', 93),
#    ('2017 American television series debuts', 61),
#    ('Days of Our Lives', 56),
#    ('Living people', 56),
#    ('2010s American drama television series', 52),
#    ('American Ninja Warrior', 41),
#    ('2000s American television series', 38),
#    ('2016 American television series debuts', 38),
#    ('American LGBT-related television shows', 33),
#    ('American soap opera actresses', 30),
#    ('Fictional American people of Irish descent', 29),
#    ('Fictional American people of English descent', 29),
#    ('Sasuke (TV series)', 26),
#    ('Ninja Warrior (franchise)', 26),
#    ('2009 American television series debuts', 26),
#    ('American television series based on Japanese television series', 26)],
#   'top_categorias_ocultas': [('Pages using citations with accessdate and no URL',
#     82),
#    ('All articles needing additional references', 66),
#    ('Articles with hCards', 61),
#    ('All articles with unsourced statements', 54),
#    ('Pages using infobox television with editor parameter', 54),
#    ('All articles with dead external links', 49),
#    ('Articles with multiple maintenance issues', 48),
#    ('All articles that need to differentiate between fact and fiction', 43),
#    ('Use mdy dates from June 2017', 41),
#    ('Pages using deprecated image syntax', 37),
#    ('All Wikipedia articles written in American English', 31),
#    ('Articles needing additional references from October 2015', 26),
#    ('All Wikipedia articles with plot summary needing attention', 26),
#    ('All articles to be expanded', 25),
#    ('Wikipedia articles with incorrect tenses', 25),
#    ('Wikipedia pages semi-protected against vandalism', 25),
#    ('Official website different in Wikidata and Wikipedia', 25),
#    ('Use American English from June 2017', 24),
#    ('Articles with dead external links from June 2016', 22),
#    ('All BLP articles lacking sources', 22)]},
#  20: {'top_categorias': [('The Walking Dead (TV series) episodes', 229),
#    ('The Walking Dead characters', 189),
#    ('2017 American television seasons', 148),
#    ('Characters created by Robert Kirkman', 142),
#    ('Fear the Walking Dead', 104),
#    ('2018 American television seasons', 85),
#    ('Fictional characters from Georgia (U.S. state)', 68),
#    ('Comics characters introduced in 2003', 59),
#    ('Fictional mass murderers', 54),
#    ('2016 American television seasons', 53),
#    ('The Walking Dead', 52),
#    ('Fictional amputees', 51),
#    ('Fictional torturers', 51),
#    ('Lists of American drama television series episodes', 40),
#    ('Fictional murderers', 39),
#    ('Fictional zombies and revenants', 39),
#    ('Fictional American people of Irish descent', 33),
#    ('Fictional child killers', 32),
#    ('Fictional victims of child abuse', 29),
#    ('Lists of horror television series episodes', 27)],
#   'top_categorias_ocultas': [('Official website different in Wikidata and Wikipedia',
#     194),
#    ('Pages using deprecated image syntax', 125),
#    ('Official website not in Wikidata', 88),
#    ('Comics articles needing issue citations', 71),
#    ('Pages using Timeline', 62),
#    ('All articles with unsourced statements', 60),
#    ('Articles with short description', 57),
#    ('Articles with unsourced statements from November 2014', 49),
#    ('All articles containing potentially dated statements', 40),
#    ('Webarchive template wayback links', 28),
#    ('Episode list using the default LineColor', 27),
#    ('CS1 Spanish-language sources (es)', 25),
#    ('Pages using infobox television with editor parameter', 25),
#    ('All articles to be expanded', 21),
#    ('Articles with hCards', 21),
#    ('Wikipedia articles with VIAF identifiers', 20),
#    ('Articles using Infobox video game using locally defined parameters', 20),
#    ('Articles using Wikidata infoboxes with locally defined images', 20),
#    ('Articles with unsourced statements from April 2016', 20),
#    ('Articles using small message boxes', 19)]},
#  21: {'top_categorias': [('The Office (U.S. TV series) characters', 151),
#    ('Fictional characters introduced in 2005', 122),
#    ('The Office (U.S. TV series) episodes in multiple parts', 70),
#    ('Fictional American people of English descent', 61),
#    ('Fictional receptionists', 56),
#    ('Fictional secretaries', 50),
#    ('2009 American television episodes', 47),
#    ('The Office (U.S. season 9) episodes', 46),
#    ('2007 American television episodes', 43),
#    ('The Office (U.S. season 3) episodes', 38),
#    ('The Office (U.S. season 5) episodes', 34),
#    ('The Office (U.S. season 6) episodes', 33),
#    ('The Office (U.S. season 8) episodes', 28),
#    ('Television episodes about weddings', 28),
#    ('2013 American television episodes', 27),
#    ('Fictional salespeople', 27),
#    ('Fictional American people of Scottish descent', 27),
#    ('The Office (U.S. TV series)', 26),
#    ('2012 American television seasons', 25),
#    ('2011 American television episodes', 24)],
#   'top_categorias_ocultas': [('Good articles', 201),
#    ('Tv.com template using numeric id', 113),
#    ('All articles that need to differentiate between fact and fiction', 93),
#    ('All articles with dead external links', 91),
#    ('Webarchive template wayback links', 88),
#    ('Articles that need to differentiate between fact and fiction from December 2015',
#     69),
#    ('Pages using deprecated image syntax', 63),
#    ('Use mdy dates from January 2018', 60),
#    ('All articles needing additional references', 59),
#    ('TV.com template using numeric id', 58),
#    ('Articles needing additional references from November 2012', 50),
#    ('Articles with multiple maintenance issues', 47),
#    ('Articles with permanently dead external links', 42),
#    ('Pages using infobox character with unknown parameters', 37),
#    ('Pages containing links to subscription-only content', 34),
#    ('Articles with short description', 31),
#    ('Wikipedia articles with VIAF identifiers', 29),
#    ('Wikipedia articles with LCCN identifiers', 29),
#    ('Featured lists', 25),
#    ('Television episode articles with short description for single episodes',
#     24)]},
#  22: {'top_categorias': [('Windows games', 845),
#    ('Xbox One games', 669),
#    ('PlayStation 4 games', 567),
#    ('Manga series', 499),
#    ('Xbox 360 games', 465),
#    ('Video games developed in the United States', 385),
#    ('Multiplayer and single-player video games', 369),
#    ('Funimation', 361),
#    ('Lists of anime episodes', 345),
#    ('Open world video games', 342),
#    ('MacOS games', 336),
#    ('PlayStation 3 games', 319),
#    ('Action-adventure games', 304),
#    ('ShÅ\x8dnen manga', 293),
#    ('Single-player video games', 279),
#    ('IOS games', 272),
#    ('Dragon Ball episode lists', 244),
#    ('American inventions', 241),
#    ('IOS (Apple)', 235),
#    ('Video games developed in Japan', 234)],
#   'top_categorias_ocultas': [('All articles with unsourced statements', 4741),
#    ('All articles needing additional references', 2285),
#    ('Articles containing Japanese-language text', 2185),
#    ('Webarchive template wayback links', 1928),
#    ('CS1 Japanese-language sources (ja)', 1852),
#    ('All articles containing potentially dated statements', 1413),
#    ('Wikipedia articles with GND identifiers', 1363),
#    ('CS1 uses Japanese-language script (ja)', 1147),
#    ('Articles using Infobox video game using locally defined parameters',
#     1145),
#    ('Articles using Wikidata infoboxes with locally defined images', 1131),
#    ('Official website different in Wikidata and Wikipedia', 1131),
#    ('All articles with dead external links', 1014),
#    ('Pages using deprecated image syntax', 958),
#    ('Articles with Japanese-language external links', 817),
#    ('Articles using Video game reviews template in single platform mode', 773),
#    ('Articles with permanently dead external links', 643),
#    ('Articles using small message boxes', 619),
#    ('Wikipedia articles with LCCN identifiers', 616),
#    ('All articles to be expanded', 591),
#    ('Pages using RFC magic links', 546)]},
#  23: {'top_categorias': [('Coronation Street characters', 71),
#    ('Fictional bartenders', 26),
#    ('Fictional businesspeople', 23),
#    ('Coronation Street', 22),
#    ('Living people', 17),
#    ('Fictional victims of kidnapping', 16),
#    ('Fictional British people', 16),
#    ('Lists of Coronation Street characters', 15),
#    ('Television series by ITV Studios', 13),
#    ('Fictional English people of Irish descent', 13),
#    ('Fictional English people', 12),
#    ('Fictional factory workers', 11),
#    ('Fictional British people of Irish descent', 11),
#    ('English television actresses', 10),
#    ('Fictional characters introduced in 2006', 10),
#    ('1960 British television programme debuts', 9),
#    ('British television soap operas', 9),
#    ('Black-and-white British television programmes', 9),
#    ('English-language television programs', 9),
#    ('Fictional streets and roads', 9)],
#   'top_categorias_ocultas': [('Use British English from March 2014', 38),
#    ('Use dmy dates from March 2014', 28),
#    ('All articles with unsourced statements', 27),
#    ('Pages using deprecated image syntax', 24),
#    ('Webarchive template wayback links', 16),
#    ('Articles with hCards', 16),
#    ('All articles needing additional references', 16),
#    ('All articles with dead external links', 11),
#    ('Pages using citations with accessdate and no URL', 11),
#    ('Use dmy dates from March 2011', 10),
#    ('Use dmy dates from October 2013', 10),
#    ('CS1 maint: Extra text: authors list', 10),
#    ('Use British English from January 2014', 9),
#    ('Articles containing potentially dated statements from 2016', 9),
#    ('All articles containing potentially dated statements', 9),
#    ('Articles containing potentially dated statements from 2013', 9),
#    ('Articles with unsourced statements from December 2008', 9),
#    ('Articles with unsourced statements from February 2012', 9),
#    ('Articles needing additional references from February 2010', 9),
#    ('Spoken articles', 9)]}}

# %%
def make_prompt(category_llm, top_categories):
    top_cats_str = ", ".join([cat for cat, _ in top_categories])
    prompt = f"""
You are an accurate semantic evaluator. Evaluate the relevance of the following category created by an LLM model relative to a community's top Wikipedia categories.

LLM category: "{category_llm}"
Top Wikipedia categories: "{top_cats_str}"

Return only a number between 0 and 1, where 0 means no semantic relationship and 1 means complete semantic relationship.
"""
    return prompt

# %%
def evaluate_correlation(category_llm, top_categories):
    prompt = make_prompt(category_llm, top_categories)
    url = "http://localhost:11434/api/generate"
    data = {
        "model": "gpt-oss:20b",
        "prompt": prompt,
        "stream": False,
        "options": {
            "seed": 42,
            "top_k": 1,
            "top_p": 1,
            "temperature": 0
        }
    }

    url = "http://localhost:11434/api/generate"
    headers = {"Content-Type": "application/json"}

    try:
        resp = requests.post(url, headers=headers, json=data, timeout=3000)
        resp.raise_for_status()
        result = resp.json()
        return result.get("response", "").strip().lower()
    except Exception as e:
        print(f"Erro ao categorizar: {e}")
        return "erro"

# %%
import pandas as pd

scores = []

for idx, row in df.iterrows():
    community_id = row['community_id']
    category_llm = row['category']
    top_categories = top20_per_community_wiki.get(community_id, {}).get('top_categorias', [])
    
    score = evaluate_correlation(category_llm, top_categories)
    scores.append(score)

df['llm_correlation'] = scores

# %%
df
# Out:
#    algorithm  community_id                               comm_name  \
# 0    louvain             0              Middle, Earth, Rings, Lord
# 1    louvain             1                  Song, You, Love, Album
# 2    louvain             2        India, Indian, Cricket, National
# 3    louvain             3  Football, League, Basketball, Baseball
# 4    louvain             4                Vegas, Las, Card, Casino
# 5    louvain             5           Golf, Open, Championship, Pga
# 6    louvain             6             Cup, Surname, United, World
# 7    louvain             7               Top, America, Next, Model
# 8    louvain             8         History, Church, Roman, Ancient
# 9    louvain             9            Law, Management, Market, Tax
# 10   louvain            10          Film, Series, Season, Episodes
# 11   louvain            11              World, War, South, History
# 12   louvain            12                 Little, Old, Baby, Mary
# 13   louvain            13              Gun, Laws, New, California
# 14   louvain            14          Cell, History, Cuisine, System
# 15   louvain            15          Power, Energy, System, History
# 16   louvain            16                Titanic, Rms, Seas, Ship
# 17   louvain            17          Season, Vampire, Diaries, Home
# 18   louvain            18              States, United, New, State
# 19   louvain            19                Brady, Series, Days, Our
# 20   louvain            20             Dead, Walking, Season, Fear
# 21   louvain            21          Office, Season, Michael, Paper
# 22   louvain            22     Episodes, Computer, Video, Software
# 23   louvain            23  Coronation, Street, Characters, Barlow
#
#                                       keywords_string  num_keywords  \
# 0   middle, earth, rings, lord, film, series, hobb...            10
# 1   song, you, love, album, music, don, all, your,...            10
# 2   india, indian, cricket, national, pakistan, fi...            10
# 3   football, league, basketball, baseball, season...            10
# 4   vegas, las, card, casino, nascar, poker, game,...            10
# 5   golf, open, championship, pga, tour, cup, club...            10
# 6   cup, surname, united, world, football, kingdom...            10
# 7   top, america, next, model, cycle, wedding, sea...            10
# 8   history, church, roman, ancient, theory, socia...            10
# 9   law, management, market, tax, economics, busin...            10
# 10  film, series, season, episodes, characters, ma...            10
# 11  world, war, south, history, canada, olympics, ...            10
# 12  little, old, baby, mary, rain, down, song, man...            10
# 13  gun, laws, new, california, carry, united, sta...            10
# 14  cell, history, cuisine, system, human, medical...            10
# 15  power, energy, system, history, water, engine,...            10
# 16  titanic, rms, seas, ship, class, ships, film, ...            10
# 17  season, vampire, diaries, home, series, away, ...            10
# 18  states, united, new, state, act, york, america...            10
# 19  brady, series, days, our, lives, dimera, ninja...            10
# 20  dead, walking, season, fear, grimes, greene, p...            10
# 21  office, season, michael, paper, series, day, n...            10
# 22  episodes, computer, video, software, game, dat...            10
# 23  coronation, street, characters, barlow, connor...            10
#
#                            category llm_correlation
# 0                 lord of the rings            0.95
# 1                        love songs             0.1
# 2        south asian sports culture             0.1
# 3                    sports leagues             0.9
# 4               vegas casino racing             0.4
# 5                  golf tournaments            0.95
# 6   football clubs and competitions             0.9
# 7                 fashion & apparel            0.85
# 8             ancient roman culture             0.4
# 9                  business finance             0.9
# 10                        film & tv             0.9
# 11         global historical events             0.4
# 12                   nursery rhymes               1
# 13                   state gun laws            0.95
# 14         human health & nutrition             0.8
# 15        energy and transportation            0.45
# 16            titanic maritime film             0.1
# 17                television series             0.9
# 18            united states history            0.95
# 19               tv show characters             0.4
# 20                 the walking dead            0.95
# 21                       the office             0.9
# 22            video game technology            0.35
# 23                british tv dramas             0.6

# %%
df['llm_correlation'] = pd.to_numeric(df['llm_correlation'], errors='coerce')

# %%
df.describe()
# Out:
#        community_id  num_keywords  llm_correlation
# count     24.000000          24.0        24.000000
# mean      11.500000          10.0         0.670833
# std        7.071068           0.0         0.315511
# min        0.000000          10.0         0.100000
# 25%        5.750000          10.0         0.400000
# 50%       11.500000          10.0         0.875000
# 75%       17.250000          10.0         0.912500
# max       23.000000          10.0         1.000000

# %%
threshold = 0.7  # acima disso consideramos que bateu com a Wikipedia

df['llm_match'] = df['llm_correlation'] >= threshold
mean_score = df['llm_correlation'].mean()
top_50_percent = df[df['llm_correlation'] >= df['llm_correlation'].quantile(0.5)]

print(f"Mean LLM Correlation Score: {mean_score}")
print(f"Top 50% Communities based on LLM Correlation:\n{top_50_percent}")
# Out:
# Mean LLM Correlation Score: 0.6708333333333334
# Top 50% Communities based on LLM Correlation:
#    algorithm  community_id                               comm_name  \
# 0    louvain             0              Middle, Earth, Rings, Lord
# 3    louvain             3  Football, League, Basketball, Baseball
# 5    louvain             5           Golf, Open, Championship, Pga
# 6    louvain             6             Cup, Surname, United, World
# 9    louvain             9            Law, Management, Market, Tax
# 10   louvain            10          Film, Series, Season, Episodes
# 12   louvain            12                 Little, Old, Baby, Mary
# 13   louvain            13              Gun, Laws, New, California
# 17   louvain            17          Season, Vampire, Diaries, Home
# 18   louvain            18              States, United, New, State
# 20   louvain            20             Dead, Walking, Season, Fear
# 21   louvain            21          Office, Season, Michael, Paper
#
#                                       keywords_string  num_keywords  \
# 0   middle, earth, rings, lord, film, series, hobb...            10
# 3   football, league, basketball, baseball, season...            10
# 5   golf, open, championship, pga, tour, cup, club...            10
# 6   cup, surname, united, world, football, kingdom...            10
# 9   law, management, market, tax, economics, busin...            10
# 10  film, series, season, episodes, characters, ma...            10
# 12  little, old, baby, mary, rain, down, song, man...            10
# 13  gun, laws, new, california, carry, united, sta...            10
# 17  season, vampire, diaries, home, series, away, ...            10
# 18  states, united, new, state, act, york, america...            10
# 20  dead, walking, season, fear, grimes, greene, p...            10
# 21  office, season, michael, paper, series, day, n...            10
#
#                            category  llm_correlation  llm_match
# 0                 lord of the rings             0.95       True
# 3                    sports leagues             0.90       True
# 5                  golf tournaments             0.95       True
# 6   football clubs and competitions             0.90       True
# 9                  business finance             0.90       True
# 10                        film & tv             0.90       True
# 12                   nursery rhymes             1.00       True
# 13                   state gun laws             0.95       True
# 17                television series             0.90       True
# 18            united states history             0.95       True
# 20                 the walking dead             0.95       True
# 21                       the office             0.90       True
